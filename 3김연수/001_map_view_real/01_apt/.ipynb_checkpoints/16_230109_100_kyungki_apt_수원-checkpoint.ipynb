# %% [markdown]
#     16_230109_100_kyungki_apt_수원
#      4-3 section
#
#      data : 서울시 대학 및 전문대학 DB 정보 (한국어)

# %%
#1. package load
import requests
import json
import os
import math
import time
import pandas as pd
import numpy as np
import geopandas as gpd
import folium
import matplotlib.pyplot as plt

from shapely.geometry import mapping, shape, Point, Polygon, LineString
from folium import plugins
from folium.plugins import MarkerCluster, HeatMap
print('슝~')
# Out:
# 슝~

# %%
#2. data load  ...SGIS data 가져오기 # SGIS API 사이트의 본인의 consumer_key, consumer_secret를 입력합니다.
consumer_key = '2f74504a63224ee09f2b'       # 서비스ID
consumer_secret =  '63a0ffef893e43a48ae2' # 보안Key

# %%
#2. data load  ... SGIS data 가져오기 # SGIS ACCESS TOKEN을 리턴 해주는 함수
def get_access_token(consumer_key, consumer_secret) -> None:
    temp_res = requests.get(
        url="https://sgisapi.kostat.go.kr/OpenAPI3/auth/authentication.json",
        params={
            "consumer_key": consumer_key,
            "consumer_secret": consumer_secret
        }
    )

    access_token = temp_res.json()["result"]["accessToken"]
   
    return access_token
print('슝~')
# Out:
# 슝~

# %%
#9 Folium를 활용한 공간 데이터 시각화
### 전국도시철도역사정보표준데이터 가져오기

apt_df = pd.read_excel("/aiffel/aiffel/0000_AIFFELTHON/3김연수/002_data_dir/002_apt_data/apt_수원_526.xls")
apt_df.head()
# Out:
#    시군명  공동주택구분        공동주택명정보 읍면동주소    지번주소     사용검사일자  층수  동수   세대수 의무관리대상여부
# 0  수원시     NaN             CJ   인계동   209-7 2001-05-29  15   1   211        Y
# 1  수원시     NaN      LG동수원자이3차   망포동     698 2003-06-27  25   7   924        Y
# 2  수원시     NaN         L·G빌리지   금곡동     530 1998-11-28  20  38  3234        Y
# 3  수원시     NaN           SK한화   정자동     918 2002-01-21  25   6   520        Y
# 4  수원시     NaN  STX KAN 1,2단지   이목동  917918 2013-02-28  26  13   947        Y

# %%
apt_df.drop(["공동주택구분"], axis=1,inplace=True)
apt_df.head()
# Out:
#    시군명        공동주택명정보 읍면동주소    지번주소     사용검사일자  층수  동수   세대수 의무관리대상여부
# 0  수원시             CJ   인계동   209-7 2001-05-29  15   1   211        Y
# 1  수원시      LG동수원자이3차   망포동     698 2003-06-27  25   7   924        Y
# 2  수원시         L·G빌리지   금곡동     530 1998-11-28  20  38  3234        Y
# 3  수원시           SK한화   정자동     918 2002-01-21  25   6   520        Y
# 4  수원시  STX KAN 1,2단지   이목동  917918 2013-02-28  26  13   947        Y

# %%
apt_df['지번주소'] = apt_df['지번주소'].astype(str)

# %%
#okok
apt_df['addr'] = '경기도 ' + apt_df[['시군명', '읍면동주소','지번주소']].agg(' '.join, axis=1)
apt_df.head()
# Out:
#    시군명        공동주택명정보 읍면동주소    지번주소     사용검사일자  층수  동수   세대수 의무관리대상여부  \
# 0  수원시             CJ   인계동   209-7 2001-05-29  15   1   211        Y
# 1  수원시      LG동수원자이3차   망포동     698 2003-06-27  25   7   924        Y
# 2  수원시         L·G빌리지   금곡동     530 1998-11-28  20  38  3234        Y
# 3  수원시           SK한화   정자동     918 2002-01-21  25   6   520        Y
# 4  수원시  STX KAN 1,2단지   이목동  917918 2013-02-28  26  13   947        Y
#
#                  addr
# 0   경기도 수원시 인계동 209-7
# 1     경기도 수원시 망포동 698
# 2     경기도 수원시 금곡동 530
# 3     경기도 수원시 정자동 918
# 4  경기도 수원시 이목동 917918

# %%
# https://sgisapi.kostat.go.kr/OpenAPI3/addr/stage.json

# %%
#5 seoul university   # 주소를 입력해 주소의 위도, 경도를 가지고 오는 함수
def get_adress_x_y(address) -> None:
    # SGIS access_token 가져오기
    access_token = get_access_token(consumer_key , consumer_secret)

    url="https://sgisapi.kostat.go.kr/OpenAPI3/addr/geocode.json"
    params={
        "accessToken": access_token,
        "address": address
    }

    temp_res = requests.get(
        url=url,
        params=params
    ).json()["result"]["resultdata"]

    return temp_res[0]["x"], temp_res[0]["y"]

print('슝~')
# Out:
# 슝~

# %%
#5 seoul university .. 주소 기반 위도,경도 추가
cnt = 0
for _, row in apt_df.iterrows():
    try:
        x, y = get_adress_x_y(row["addr"])
     
        apt_df.loc[_, "x"] = x
        apt_df.loc[_, "y"] = y
    except:
        print(row["addr"] + '은(는) 검색에 실패했습니다')
        cnt = cnt + 1

print("실패건수 : ", cnt)
apt_df.head()
# Out:
# 경기도 수원시 이목동 917918은(는) 검색에 실패했습니다
# 경기도 수원시 금곡동 435은(는) 검색에 실패했습니다
# 경기도 수원시 정자동 15311은(는) 검색에 실패했습니다
# 경기도 수원시 하동 1334은(는) 검색에 실패했습니다
# 경기도 수원시 우만동 21186은(는) 검색에 실패했습니다
# 경기도 수원시 정자동 16469은(는) 검색에 실패했습니다
# 경기도 수원시 정자동 16650은(는) 검색에 실패했습니다
# 경기도 수원시 정자동 44788은(는) 검색에 실패했습니다
# 경기도 수원시 신동 507-24은(는) 검색에 실패했습니다
# 경기도 수원시 신동 507-2은(는) 검색에 실패했습니다
# 경기도 수원시 정자동 44651은(는) 검색에 실패했습니다
# 경기도 수원시 탑동 44621은(는) 검색에 실패했습니다
# 경기도 수원시 탑동 44575은(는) 검색에 실패했습니다
# 경기도 수원시 호매실동 30072은(는) 검색에 실패했습니다
# 경기도 수원시 고색동 44685은(는) 검색에 실패했습니다
# 경기도 수원시 원천동 44711은(는) 검색에 실패했습니다
# 경기도 수원시 송죽동 381은(는) 검색에 실패했습니다
# 경기도 수원시 서둔동 418은(는) 검색에 실패했습니다
# 경기도 수원시 정자동 26451은(는) 검색에 실패했습니다
# 경기도 수원시 정자동 16589은(는) 검색에 실패했습니다
# 경기도 수원시 연무동 44870은(는) 검색에 실패했습니다
# 경기도 수원시 우만동 31107은(는) 검색에 실패했습니다
# 경기도 수원시 원천동 25934은(는) 검색에 실패했습니다
# 경기도 수원시 연무동 44671은(는) 검색에 실패했습니다
# 경기도 수원시 연무동 664-8은(는) 검색에 실패했습니다
# 경기도 수원시 오목천동 960961은(는) 검색에 실패했습니다
# 경기도 수원시 우만동 27942은(는) 검색에 실패했습니다
# 경기도 수원시 연무동 44702은(는) 검색에 실패했습니다
# 경기도 수원시 인계동 1171은(는) 검색에 실패했습니다
# 경기도 수원시 정자동 44585은(는) 검색에 실패했습니다
# 경기도 수원시 정자동 27211은(는) 검색에 실패했습니다
# 경기도 수원시 정자동 44590은(는) 검색에 실패했습니다
# 경기도 수원시 정자동 44591은(는) 검색에 실패했습니다
# 경기도 수원시 화서동 30682은(는) 검색에 실패했습니다
# 경기도 수원시 탑동 44685은(는) 검색에 실패했습니다
# 경기도 수원시 고등동 34335은(는) 검색에 실패했습니다
# 경기도 수원시 금곡동 374은(는) 검색에 실패했습니다
# 경기도 수원시 화서동 44876은(는) 검색에 실패했습니다
# 경기도 수원시 화서동 35462은(는) 검색에 실패했습니다
# 경기도 수원시 정자동 950은(는) 검색에 실패했습니다
# 경기도 수원시 화서동 184은(는) 검색에 실패했습니다
# 경기도 수원시 정자동 44704은(는) 검색에 실패했습니다
# 경기도 수원시 정자동 44866은(는) 검색에 실패했습니다
# 경기도 수원시 정자동 25235은(는) 검색에 실패했습니다
# 실패건수 :  44
#    시군명        공동주택명정보 읍면동주소    지번주소     사용검사일자  층수  동수   세대수 의무관리대상여부  \
# 0  수원시             CJ   인계동   209-7 2001-05-29  15   1   211        Y
# 1  수원시      LG동수원자이3차   망포동     698 2003-06-27  25   7   924        Y
# 2  수원시         L·G빌리지   금곡동     530 1998-11-28  20  38  3234        Y
# 3  수원시           SK한화   정자동     918 2002-01-21  25   6   520        Y
# 4  수원시  STX KAN 1,2단지   이목동  917918 2013-02-28  26  13   947        Y
#
#                  addr                 x                 y
# 0   경기도 수원시 인계동 209-7  958211.339616942  1919856.10469734
# 1     경기도 수원시 망포동 698  960682.110959915   1915404.7495117
# 2     경기도 수원시 금곡동 530  950072.363688641  1919478.84302743
# 3     경기도 수원시 정자동 918  954424.576669348  1921852.31183173
# 4  경기도 수원시 이목동 917918               NaN               NaN

# %%
#5 seoul university  ..# SGIS 좌표변환 API를 활용한 좌표변환 함수
def get_transcoord(src, dst, posX, posY) -> None:
    access_token = get_access_token(consumer_key, consumer_secret)
    url="https://sgisapi.kostat.go.kr/OpenAPI3/transformation/transcoord.json"
    params={
        "accessToken": access_token,
        "src": src, # 현재 좌표체계
        "dst": dst, # 변환할 좌표체계
        "posX": posX, # 변환할 좌표 X값
        "posY":	posY # 변환할 좌표 Y값
    }

    temp_dict = requests.get(
        url=url,
        params=params
    ).json()["result"]

    return temp_dict["posX"], temp_dict["posY"] # 변환된 좌표값 딕셔너리의 value 리턴

print('슝~')
# Out:
# 슝~

# %%
#5 seoul university  .. 좌표계가 UTM-K이므로 WSG84좌표계로 변환
for _, row in apt_df.iterrows():
    try:
        x, y = get_transcoord("EPSG:5179", "EPSG:4326", row["x"], row["y"])
    
        apt_df.loc[_, "lng"] = x
        apt_df.loc[_, "lat"] = y

    except:
        pass
apt_df.head()
# Out:
#    시군명        공동주택명정보 읍면동주소    지번주소     사용검사일자  층수  동수   세대수 의무관리대상여부  \
# 0  수원시             CJ   인계동   209-7 2001-05-29  15   1   211        Y
# 1  수원시      LG동수원자이3차   망포동     698 2003-06-27  25   7   924        Y
# 2  수원시         L·G빌리지   금곡동     530 1998-11-28  20  38  3234        Y
# 3  수원시           SK한화   정자동     918 2002-01-21  25   6   520        Y
# 4  수원시  STX KAN 1,2단지   이목동  917918 2013-02-28  26  13   947        Y
#
#                  addr                 x                 y         lng  \
# 0   경기도 수원시 인계동 209-7  958211.339616942  1919856.10469734  127.028626
# 1     경기도 수원시 망포동 698  960682.110959915   1915404.7495117  127.056731
# 2     경기도 수원시 금곡동 530  950072.363688641  1919478.84302743  126.936848
# 3     경기도 수원시 정자동 918  954424.576669348  1921852.31183173  126.985791
# 4  경기도 수원시 이목동 917918               NaN               NaN         NaN
#
#          lat
# 0  37.276688
# 1  37.236672
# 2  37.272887
# 3  37.294503
# 4        NaN

# %%
#5 seoul university  .. 시각화 .. 초기 중심값 좌표가 들어가야 합니다.

# 서울시 중심부 위도, 경도
center = [37.541, 126.986]

# map이 서울 중심부에 위치하고, zoom 레벨은 12로 시작합니다.
map = folium.Map(
    location=center,
    zoom_start=12

)

print('슝~')
# Out:
# 슝~

# %%
# #5 seoul university # 대학 이름, 위도, 경도를 가져와 시각화
# for _, row in apt_df.iterrows():
#     try:
#         folium.Marker(
#             location=[row["lat"], row["lng"]], # 좌표
#             popup=row["공동주택명정보"], # 클릭시 표시될 popup 내용
#             icon=folium.Icon(color="cadetblue", icon="info-sign") # 표시될 아이콘 설정
#         ).add_to(map)
#     except:
#         pass

# print('슝~')

# %%
#2. 프로젝트(1)  # MarkerCluster 객체 
marker_cluster = MarkerCluster().add_to(map)

#maker 객체 추가
for idx, row in apt_df.iterrows():
    try:
        folium.Marker(
            location=[apt_df.loc[idx, "lat"], apt_df.loc[idx, "lng"]],
            popup=apt_df.loc[idx, "공동주택명정보"],
            icon=folium.Icon(color="cadetblue", icon="house")            
        ).add_to(marker_cluster)
    except:
        pass

print('슝~')
# Out:
# 슝~

# %%
#5 seoul university 
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_56bb6f13714841bb8f426b4dfdb21b49%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_56bb6f13714841bb8f426b4dfdb21b49%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3 ...

# %%
map.save("/aiffel/aiffel/0000_AIFFELTHON/3김연수/003_map_xml/apt_suwon.html")

# %%
apt_df.to_csv("apt_suwon.csv", index = False)

# %%
# #2. 프로젝트(1)  # MarkerCluster 객체 
# marker_cluster = MarkerCluster().add_to(map)

# #maker 객체 추가
# for idx, row in apt_df.iterrows():
#     try:
#         folium.Marker(
#             location=[apt_df.loc[idx, "lat"], apt_df.loc[idx, "lng"]],
#             popup=apt_df.loc[idx, "공동주택명정보"],
#             icon=folium.Icon(color="cadetblue", icon="car", prefix="fa")            
#         ).add_to(marker_cluster)
#     except:
#         pass

# print('슝~')
