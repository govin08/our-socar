# %% [markdown]
#     16_230109_100_kyungki_apt_가평
#      4-3 section
#
#      data : /aiffel/aiffel/0000_AIFFELTHON/3김연수/002_data_dir/002_apt_data/apt_가평_고양시_601.xls

# %%
#1. package load
import requests
import json
import os
import math
import time
import pandas as pd
import numpy as np
import geopandas as gpd
import folium
import matplotlib.pyplot as plt

from shapely.geometry import mapping, shape, Point, Polygon, LineString
from folium import plugins
from folium.plugins import MarkerCluster, HeatMap
print('슝~')
# Out:
# 슝~

# %%
#2. data load  ...SGIS data 가져오기 # SGIS API 사이트의 본인의 consumer_key, consumer_secret를 입력합니다.
consumer_key = '2f74504a63224ee09f2b'       # 서비스ID
consumer_secret =  '63a0ffef893e43a48ae2' # 보안Key

# %%
#2. data load  ... SGIS data 가져오기 # SGIS ACCESS TOKEN을 리턴 해주는 함수
def get_access_token(consumer_key, consumer_secret) -> None:
    temp_res = requests.get(
        url="https://sgisapi.kostat.go.kr/OpenAPI3/auth/authentication.json",
        params={
            "consumer_key": consumer_key,
            "consumer_secret": consumer_secret
        }
    )

    access_token = temp_res.json()["result"]["accessToken"]
   
    return access_token
print('슝~')
# Out:
# 슝~

# %%
#9 Folium를 활용한 공간 데이터 시각화
### 전국도시철도역사정보표준데이터 가져오기

apt_df = pd.read_excel("/aiffel/aiffel/0000_AIFFELTHON/3김연수/002_data_dir/002_apt_data/apt_가평_고양시_601.xls")
apt_df.head()
# Out:
#    시군명  공동주택구분      공동주택명정보    읍면동주소   지번주소     사용검사일자  층수  동수  세대수 의무관리대상여부
# 0  가평군     NaN        가평블루핀  가평읍 읍내리  766-3 2019-09-27  19   2  119        N
# 1  가평군     NaN       가평우림필유  가평읍 대곡리    360 2006-12-26  15   2  190        Y
# 2  가평군     NaN    가평읍내주공아파트  가평읍 읍내리    270 1999-11-19  12   5  355        N
# 3  가평군     NaN  가평읍내휴먼시아2단지  가평읍 읍내리    234 2010-08-30  13   6  335        N
# 4  가평군     NaN        가평코아루  가평읍 읍내리   1053 2021-11-09  20   3  221        Y

# %%
apt_df.drop(["공동주택구분"], axis=1,inplace=True)
apt_df.head()
# Out:
#    시군명      공동주택명정보    읍면동주소   지번주소     사용검사일자  층수  동수  세대수 의무관리대상여부
# 0  가평군        가평블루핀  가평읍 읍내리  766-3 2019-09-27  19   2  119        N
# 1  가평군       가평우림필유  가평읍 대곡리    360 2006-12-26  15   2  190        Y
# 2  가평군    가평읍내주공아파트  가평읍 읍내리    270 1999-11-19  12   5  355        N
# 3  가평군  가평읍내휴먼시아2단지  가평읍 읍내리    234 2010-08-30  13   6  335        N
# 4  가평군        가평코아루  가평읍 읍내리   1053 2021-11-09  20   3  221        Y

# %%
apt_df['지번주소'] = apt_df['지번주소'].astype(str)

# %%
#okok
apt_df['addr'] = '경기도 ' + apt_df[['시군명', '읍면동주소','지번주소']].agg(' '.join, axis=1)
apt_df.head()
# Out:
#    시군명      공동주택명정보    읍면동주소   지번주소     사용검사일자  층수  동수  세대수 의무관리대상여부  \
# 0  가평군        가평블루핀  가평읍 읍내리  766-3 2019-09-27  19   2  119        N
# 1  가평군       가평우림필유  가평읍 대곡리    360 2006-12-26  15   2  190        Y
# 2  가평군    가평읍내주공아파트  가평읍 읍내리    270 1999-11-19  12   5  355        N
# 3  가평군  가평읍내휴먼시아2단지  가평읍 읍내리    234 2010-08-30  13   6  335        N
# 4  가평군        가평코아루  가평읍 읍내리   1053 2021-11-09  20   3  221        Y
#
#                     addr
# 0  경기도 가평군 가평읍 읍내리 766-3
# 1    경기도 가평군 가평읍 대곡리 360
# 2    경기도 가평군 가평읍 읍내리 270
# 3    경기도 가평군 가평읍 읍내리 234
# 4   경기도 가평군 가평읍 읍내리 1053

# %%
# https://sgisapi.kostat.go.kr/OpenAPI3/addr/stage.json

# %%
#5 seoul university   # 주소를 입력해 주소의 위도, 경도를 가지고 오는 함수
def get_adress_x_y(address) -> None:
    # SGIS access_token 가져오기
    access_token = get_access_token(consumer_key , consumer_secret)

    url="https://sgisapi.kostat.go.kr/OpenAPI3/addr/geocode.json"
    params={
        "accessToken": access_token,
        "address": address
    }

    temp_res = requests.get(
        url=url,
        params=params
    ).json()["result"]["resultdata"]

    return temp_res[0]["x"], temp_res[0]["y"]

print('슝~')
# Out:
# 슝~

# %%
#5 seoul university .. 주소 기반 위도,경도 추가
cnt = 0
for _, row in apt_df.iterrows():
    try:
        x, y = get_adress_x_y(row["addr"])
     
        apt_df.loc[_, "x"] = x
        apt_df.loc[_, "y"] = y
    except:
        print(row["addr"] + '은(는) 검색에 실패했습니다')
        cnt = cnt + 1

print("실패건수 : ", cnt)
apt_df.head()
# Out:
# 경기도 가평군 가평읍 읍내리 1053은(는) 검색에 실패했습니다
# 경기도 가평군 설악면 선촌리 44586은(는) 검색에 실패했습니다
# 경기도 고양시 향동동 501은(는) 검색에 실패했습니다
# 경기도 고양시 향동동 570은(는) 검색에 실패했습니다
# 경기도 고양시 향동동 517은(는) 검색에 실패했습니다
# 경기도 고양시 향동동 421은(는) 검색에 실패했습니다
# 경기도 고양시 향동동 571은(는) 검색에 실패했습니다
# 경기도 고양시 향동동 557은(는) 검색에 실패했습니다
# 경기도 고양시 향동동 552은(는) 검색에 실패했습니다
# 경기도 고양시 원흥동 615은(는) 검색에 실패했습니다
# 경기도 고양시 가좌동 1090은(는) 검색에 실패했습니다
# 경기도 고양시 가좌동 1089은(는) 검색에 실패했습니다
# 경기도 고양시 가좌동 1088은(는) 검색에 실패했습니다
# 경기도 고양시 가좌동 1087은(는) 검색에 실패했습니다
# 경기도 고양시 가좌동 1086은(는) 검색에 실패했습니다
# 경기도 고양시 가좌동 1105은(는) 검색에 실패했습니다
# 경기도 고양시 주엽동 75은(는) 검색에 실패했습니다
# 경기도 고양시 주엽동 73은(는) 검색에 실패했습니다
# 경기도 고양시 주엽동 83은(는) 검색에 실패했습니다
# 경기도 고양시 주엽동 81은(는) 검색에 실패했습니다
# 경기도 고양시 주엽동 101은(는) 검색에 실패했습니다
# 경기도 고양시 주엽동 84은(는) 검색에 실패했습니다
# 경기도 고양시 주엽동 86은(는) 검색에 실패했습니다
# 경기도 고양시 주엽동 90은(는) 검색에 실패했습니다
# 경기도 고양시 주엽동 98은(는) 검색에 실패했습니다
# 경기도 고양시 주엽동 36은(는) 검색에 실패했습니다
# 경기도 고양시 주엽동 38은(는) 검색에 실패했습니다
# 경기도 고양시 주엽동 43은(는) 검색에 실패했습니다
# 경기도 고양시 주엽동 46은(는) 검색에 실패했습니다
# 경기도 고양시 주엽동 49은(는) 검색에 실패했습니다
# 경기도 고양시 주엽동 50은(는) 검색에 실패했습니다
# 경기도 고양시 주엽동 65은(는) 검색에 실패했습니다
# 경기도 고양시 주엽동 63은(는) 검색에 실패했습니다
# 경기도 고양시 주엽동 60은(는) 검색에 실패했습니다
# 경기도 고양시 마두동 757은(는) 검색에 실패했습니다
# 경기도 고양시 마두동 783은(는) 검색에 실패했습니다
# 경기도 고양시 마두동 787은(는) 검색에 실패했습니다
# 경기도 고양시 마두동 789은(는) 검색에 실패했습니다
# 경기도 고양시 마두동 789은(는) 검색에 실패했습니다
# 경기도 고양시 마두동 806은(는) 검색에 실패했습니다
# 경기도 고양시 마두동 796은(는) 검색에 실패했습니다
# 경기도 고양시 마두동 794은(는) 검색에 실패했습니다
# 경기도 고양시 성사동 415-0은(는) 검색에 실패했습니다
# 경기도 고양시 신원동 959은(는) 검색에 실패했습니다
# 경기도 고양시 향동동 407은(는) 검색에 실패했습니다
# 경기도 고양시 향동동 405은(는) 검색에 실패했습니다
# 경기도 고양시 토당동 861-1외1은(는) 검색에 실패했습니다
# 경기도 고양시 토당동 80은(는) 검색에 실패했습니다
# 경기도 고양시 토당동 282-2은(는) 검색에 실패했습니다
# 경기도 고양시 식사동 621-10은(는) 검색에 실패했습니다
# 경기도 고양시 토당동 250은(는) 검색에 실패했습니다
# 경기도 고양시 토당동 434-3은(는) 검색에 실패했습니다
# 경기도 고양시 토당동 860외7은(는) 검색에 실패했습니다
# 경기도 고양시 토당동 259은(는) 검색에 실패했습니다
# 경기도 고양시 관산동 1015은(는) 검색에 실패했습니다
# 경기도 고양시 덕이동 1106은(는) 검색에 실패했습니다
# 경기도 고양시 덕이동 1037은(는) 검색에 실패했습니다
# 경기도 고양시 덕이동 676-1은(는) 검색에 실패했습니다
# 경기도 고양시 덕이동 1521은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 220은(는) 검색에 실패했습니다
# 경기도 고양시 고양동 44899은(는) 검색에 실패했습니다
# 경기도 고양시 덕이동 382-13은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 653-38외7은(는) 검색에 실패했습니다
# 경기도 고양시 토당동 292-34은(는) 검색에 실패했습니다
# 경기도 고양시 성사동 494-10은(는) 검색에 실패했습니다
# 경기도 고양시 토당동 292-38은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 773은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 692은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 771은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 769은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 767은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 702은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 699은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 700은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 697은(는) 검색에 실패했습니다
# 경기도 고양시 주엽동 17은(는) 검색에 실패했습니다
# 경기도 고양시 주엽동 15은(는) 검색에 실패했습니다
# 경기도 고양시 주엽동 138은(는) 검색에 실패했습니다
# 경기도 고양시 주엽동 136은(는) 검색에 실패했습니다
# 경기도 고양시 주엽동 133은(는) 검색에 실패했습니다
# 경기도 고양시 주엽동 135은(는) 검색에 실패했습니다
# 경기도 고양시 주엽동 117은(는) 검색에 실패했습니다
# 경기도 고양시 주엽동 120은(는) 검색에 실패했습니다
# 경기도 고양시 주엽동 128은(는) 검색에 실패했습니다
# 경기도 고양시 주엽동 126은(는) 검색에 실패했습니다
# 경기도 고양시 주엽동 1은(는) 검색에 실패했습니다
# 경기도 고양시 주엽동 5은(는) 검색에 실패했습니다
# 경기도 고양시 주엽동 32은(는) 검색에 실패했습니다
# 경기도 고양시 주엽동 29은(는) 검색에 실패했습니다
# 경기도 고양시 주엽동 6은(는) 검색에 실패했습니다
# 경기도 고양시 주엽동 8은(는) 검색에 실패했습니다
# 경기도 고양시 주엽동 14은(는) 검색에 실패했습니다
# 경기도 고양시 주엽동 14은(는) 검색에 실패했습니다
# 경기도 고양시 주엽동 12은(는) 검색에 실패했습니다
# 경기도 고양시 주엽동 23은(는) 검색에 실패했습니다
# 경기도 고양시 주엽동 23은(는) 검색에 실패했습니다
# 경기도 고양시 성사동 404-8은(는) 검색에 실패했습니다
# 경기도 고양시 성사동 404-7은(는) 검색에 실패했습니다
# 경기도 고양시 성사동 422-2은(는) 검색에 실패했습니다
# 경기도 고양시 성사동 422-3은(는) 검색에 실패했습니다
# 경기도 고양시 현천동 44715은(는) 검색에 실패했습니다
# 경기도 고양시 성사동 404-28은(는) 검색에 실패했습니다
# 경기도 고양시 정발산동 1144은(는) 검색에 실패했습니다
# 경기도 고양시 정발산동 1141은(는) 검색에 실패했습니다
# 경기도 고양시 정발산동 1111은(는) 검색에 실패했습니다
# 경기도 고양시 정발산동 1116은(는) 검색에 실패했습니다
# 경기도 고양시 정발산동 1260은(는) 검색에 실패했습니다
# 경기도 고양시 정발산동 1266은(는) 검색에 실패했습니다
# 경기도 고양시 정발산동 1269은(는) 검색에 실패했습니다
# 경기도 고양시 정발산동 13541356은(는) 검색에 실패했습니다
# 경기도 고양시 정발산동 1170은(는) 검색에 실패했습니다
# 경기도 고양시 마두동 755은(는) 검색에 실패했습니다
# 경기도 고양시 마두동 739은(는) 검색에 실패했습니다
# 경기도 고양시 마두동 732은(는) 검색에 실패했습니다
# 경기도 고양시 마두동 734은(는) 검색에 실패했습니다
# 경기도 고양시 마두동 717은(는) 검색에 실패했습니다
# 경기도 고양시 마두동 719은(는) 검색에 실패했습니다
# 경기도 고양시 토당동 19-0은(는) 검색에 실패했습니다
# 경기도 고양시 고양동 1072-0은(는) 검색에 실패했습니다
# 경기도 고양시 사리현동 186187은(는) 검색에 실패했습니다
# 경기도 고양시 사리현동 189은(는) 검색에 실패했습니다
# 경기도 고양시 고양동 199-6은(는) 검색에 실패했습니다
# 경기도 고양시 주교동 44667은(는) 검색에 실패했습니다
# 경기도 고양시 고양동 197외7은(는) 검색에 실패했습니다
# 경기도 고양시 관산동 118-2은(는) 검색에 실패했습니다
# 경기도 고양시 원흥동 635은(는) 검색에 실패했습니다
# 경기도 고양시 원흥동 619은(는) 검색에 실패했습니다
# 경기도 고양시 원흥동 669은(는) 검색에 실패했습니다
# 경기도 고양시 원흥동 670은(는) 검색에 실패했습니다
# 경기도 고양시 원흥동 677은(는) 검색에 실패했습니다
# 경기도 고양시 삼송동 306은(는) 검색에 실패했습니다
# 경기도 고양시 삼송동 332은(는) 검색에 실패했습니다
# 경기도 고양시 삼송동 311은(는) 검색에 실패했습니다
# 경기도 고양시 삼송동 331은(는) 검색에 실패했습니다
# 경기도 고양시 삼송동 293은(는) 검색에 실패했습니다
# 경기도 고양시 오금동 619-3은(는) 검색에 실패했습니다
# 경기도 고양시 원흥동 630은(는) 검색에 실패했습니다
# 경기도 고양시 토당동 879은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 173-1은(는) 검색에 실패했습니다
# 경기도 고양시 토당동 15797은(는) 검색에 실패했습니다
# 경기도 고양시 성사동 494-29은(는) 검색에 실패했습니다
# 경기도 고양시 성사동 494-5은(는) 검색에 실패했습니다
# 경기도 고양시 토당동 392-1은(는) 검색에 실패했습니다
# 경기도 고양시 토당동 399-0은(는) 검색에 실패했습니다
# 경기도 고양시 관산동 178-57은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 973은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 983은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 983은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 1002은(는) 검색에 실패했습니다
# 경기도 고양시 성사동 705-15은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 1090은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 1074은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 1113은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 1073은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 1096은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 1068은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 1088은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 1092은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 1103은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 1102은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 1064은(는) 검색에 실패했습니다
# 경기도 고양시 토당동 36465은(는) 검색에 실패했습니다
# 경기도 고양시 주교동 597-12은(는) 검색에 실패했습니다
# 경기도 고양시 토당동 385-7은(는) 검색에 실패했습니다
# 경기도 고양시 토당동 36161은(는) 검색에 실패했습니다
# 경기도 고양시 고양동 993은(는) 검색에 실패했습니다
# 경기도 고양시 성사동 493-0은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 796은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 791은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 798은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 799은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 788은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 785787은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 783은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 781은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 793은(는) 검색에 실패했습니다
# 경기도 고양시 풍동 1223은(는) 검색에 실패했습니다
# 경기도 고양시 풍동 1292은(는) 검색에 실패했습니다
# 경기도 고양시 중산동 1286은(는) 검색에 실패했습니다
# 경기도 고양시 풍동 1265은(는) 검색에 실패했습니다
# 경기도 고양시 중산동 1267은(는) 검색에 실패했습니다
# 경기도 고양시 풍동 1268은(는) 검색에 실패했습니다
# 경기도 고양시 풍동 1258은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 1091은(는) 검색에 실패했습니다
# 경기도 고양시 관산동 981은(는) 검색에 실패했습니다
# 경기도 고양시 주교동 572-0은(는) 검색에 실패했습니다
# 경기도 고양시 일산동 1818-0은(는) 검색에 실패했습니다
# 경기도 고양시 성사동 719은(는) 검색에 실패했습니다
# 경기도 고양시 성사동 723은(는) 검색에 실패했습니다
# 경기도 고양시 성사동 724은(는) 검색에 실패했습니다
# 경기도 고양시 성사동 730은(는) 검색에 실패했습니다
# 경기도 고양시 성사동 731은(는) 검색에 실패했습니다
# 경기도 고양시 성사동 727은(는) 검색에 실패했습니다
# 경기도 고양시 성사동 726은(는) 검색에 실패했습니다
# 경기도 고양시 성사동 725은(는) 검색에 실패했습니다
# 경기도 고양시 토당동 18172은(는) 검색에 실패했습니다
# 경기도 고양시 정발산동 786은(는) 검색에 실패했습니다
# 경기도 고양시 정발산동 720은(는) 검색에 실패했습니다
# 경기도 고양시 정발산동 721은(는) 검색에 실패했습니다
# 경기도 고양시 정발산동 696은(는) 검색에 실패했습니다
# 경기도 고양시 정발산동 676은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 204-5은(는) 검색에 실패했습니다
# 경기도 고양시 중산동 44611은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 222-0은(는) 검색에 실패했습니다
# 경기도 고양시 고양동 454은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 653-9은(는) 검색에 실패했습니다
# 경기도 고양시 성사동 869은(는) 검색에 실패했습니다
# 경기도 고양시 성사동 860은(는) 검색에 실패했습니다
# 경기도 고양시 도내동 1006은(는) 검색에 실패했습니다
# 경기도 고양시 원흥동 717은(는) 검색에 실패했습니다
# 경기도 고양시 도내동 983은(는) 검색에 실패했습니다
# 경기도 고양시 도내동 1010은(는) 검색에 실패했습니다
# 경기도 고양시 도내동 1011은(는) 검색에 실패했습니다
# 경기도 고양시 도내동 1103은(는) 검색에 실패했습니다
# 경기도 고양시 도내동 1107은(는) 검색에 실패했습니다
# 경기도 고양시 원흥동 617은(는) 검색에 실패했습니다
# 경기도 고양시 식사동 1510은(는) 검색에 실패했습니다
# 경기도 고양시 식사동 1565은(는) 검색에 실패했습니다
# 경기도 고양시 식사동 1487은(는) 검색에 실패했습니다
# 경기도 고양시 식사동 1498은(는) 검색에 실패했습니다
# 경기도 고양시 식사동 1504은(는) 검색에 실패했습니다
# 경기도 고양시 식사동 1528은(는) 검색에 실패했습니다
# 경기도 고양시 식사동 1533은(는) 검색에 실패했습니다
# 경기도 고양시 관산동 126은(는) 검색에 실패했습니다
# 경기도 고양시 토당동 900-5은(는) 검색에 실패했습니다
# 경기도 고양시 고양동 414-1(-17)은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 633-67은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 650-78은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 634-45은(는) 검색에 실패했습니다
# 경기도 고양시 관산동 134-0은(는) 검색에 실패했습니다
# 경기도 고양시 식사동 910은(는) 검색에 실패했습니다
# 경기도 고양시 식사동 1474은(는) 검색에 실패했습니다
# 경기도 고양시 일산동 1945은(는) 검색에 실패했습니다
# 경기도 고양시 탄현동 1640은(는) 검색에 실패했습니다
# 경기도 고양시 탄현동 1650은(는) 검색에 실패했습니다
# 경기도 고양시 식사동 852은(는) 검색에 실패했습니다
# 경기도 고양시 일산동 2125, 2121은(는) 검색에 실패했습니다
# 경기도 고양시 탄현동 1634은(는) 검색에 실패했습니다
# 경기도 고양시 성사동 488-56은(는) 검색에 실패했습니다
# 경기도 고양시 토당동 402-0은(는) 검색에 실패했습니다
# 경기도 고양시 토당동 26-0은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 644-1,-43은(는) 검색에 실패했습니다
# 경기도 고양시 토당동 873은(는) 검색에 실패했습니다
# 경기도 고양시 성사동 496-5은(는) 검색에 실패했습니다
# 경기도 고양시 성사동 519-51은(는) 검색에 실패했습니다
# 경기도 고양시 성사동 519-53은(는) 검색에 실패했습니다
# 경기도 고양시 토당동 99-54은(는) 검색에 실패했습니다
# 경기도 고양시 토당동 99-39은(는) 검색에 실패했습니다
# 경기도 고양시 토당동 36192은(는) 검색에 실패했습니다
# 경기도 고양시 마두동 821은(는) 검색에 실패했습니다
# 경기도 고양시 마두동 859은(는) 검색에 실패했습니다
# 경기도 고양시 마두동 861은(는) 검색에 실패했습니다
# 경기도 고양시 마두동 867은(는) 검색에 실패했습니다
# 경기도 고양시 마두동 1007은(는) 검색에 실패했습니다
# 경기도 고양시 마두동 1006은(는) 검색에 실패했습니다
# 경기도 고양시 마두동 1004은(는) 검색에 실패했습니다
# 경기도 고양시 마두동 812은(는) 검색에 실패했습니다
# 경기도 고양시 벽제동 112-6은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 235-1은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 235-3은(는) 검색에 실패했습니다
# 경기도 고양시 성사동 488-40은(는) 검색에 실패했습니다
# 경기도 고양시 관산동 996은(는) 검색에 실패했습니다
# 경기도 고양시 풍동 1555은(는) 검색에 실패했습니다
# 경기도 고양시 관산동 338-39 외 1(338-4)은(는) 검색에 실패했습니다
# 경기도 고양시 덕이동 1076은(는) 검색에 실패했습니다
# 경기도 고양시 지축동 498-6은(는) 검색에 실패했습니다
# 경기도 고양시 지축동 569-8은(는) 검색에 실패했습니다
# 경기도 고양시 지축동 645-2은(는) 검색에 실패했습니다
# 경기도 고양시 덕이동 277-10은(는) 검색에 실패했습니다
# 경기도 고양시 고양동 399은(는) 검색에 실패했습니다
# 경기도 고양시 성석동 1077은(는) 검색에 실패했습니다
# 경기도 고양시 성사동 503-0은(는) 검색에 실패했습니다
# 경기도 고양시 탄현동 121외 6은(는) 검색에 실패했습니다
# 경기도 고양시 장항동 1761은(는) 검색에 실패했습니다
# 경기도 고양시 장항동 1762은(는) 검색에 실패했습니다
# 경기도 고양시 탄현동 130은(는) 검색에 실패했습니다
# 경기도 고양시 탄현동 1470은(는) 검색에 실패했습니다
# 경기도 고양시 탄현동 1578은(는) 검색에 실패했습니다
# 경기도 고양시 탄현동 1579은(는) 검색에 실패했습니다
# 경기도 고양시 탄현동 1584은(는) 검색에 실패했습니다
# 경기도 고양시 탄현동 1582은(는) 검색에 실패했습니다
# 경기도 고양시 탄현동 1583은(는) 검색에 실패했습니다
# 경기도 고양시 탄현동 1585은(는) 검색에 실패했습니다
# 경기도 고양시 탄현동 1485은(는) 검색에 실패했습니다
# 경기도 고양시 탄현동 1487은(는) 검색에 실패했습니다
# 경기도 고양시 탄현동 1484은(는) 검색에 실패했습니다
# 경기도 고양시 탄현동 1481은(는) 검색에 실패했습니다
# 경기도 고양시 탄현동 1477은(는) 검색에 실패했습니다
# 경기도 고양시 탄현동 1479은(는) 검색에 실패했습니다
# 경기도 고양시 탄현동 1480은(는) 검색에 실패했습니다
# 경기도 고양시 탄현동 1476은(는) 검색에 실패했습니다
# 경기도 고양시 탄현동 1473은(는) 검색에 실패했습니다
# 경기도 고양시 토당동 853외4은(는) 검색에 실패했습니다
# 경기도 고양시 고양동 735은(는) 검색에 실패했습니다
# 경기도 고양시 고양동 1121(736)은(는) 검색에 실패했습니다
# 경기도 고양시 고양동 720은(는) 검색에 실패했습니다
# 경기도 고양시 고양동 719은(는) 검색에 실패했습니다
# 경기도 고양시 고양동 734은(는) 검색에 실패했습니다
# 경기도 고양시 고양동 730은(는) 검색에 실패했습니다
# 경기도 고양시 고양동 724은(는) 검색에 실패했습니다
# 경기도 고양시 고양동 752은(는) 검색에 실패했습니다
# 경기도 고양시 고양동 725은(는) 검색에 실패했습니다
# 경기도 고양시 토당동 70은(는) 검색에 실패했습니다
# 경기도 고양시 풍동 1801은(는) 검색에 실패했습니다
# 경기도 고양시 덕이동 1524은(는) 검색에 실패했습니다
# 경기도 고양시 덕이동 1540은(는) 검색에 실패했습니다
# 경기도 고양시 덕이동 1529은(는) 검색에 실패했습니다
# 경기도 고양시 덕이동 1534은(는) 검색에 실패했습니다
# 경기도 고양시 덕이동 1535은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 1054은(는) 검색에 실패했습니다
# 경기도 고양시 토당동 298은(는) 검색에 실패했습니다
# 경기도 고양시 토당동 33239은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 895은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 938은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 903904은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 934은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 905은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 946은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 953은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 958은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 621은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 630외1은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 650은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 205-25은(는) 검색에 실패했습니다
# 경기도 고양시 행신동 617-9은(는) 검색에 실패했습니다
# 경기도 고양시 향동동 406은(는) 검색에 실패했습니다
# 경기도 고양시 관산동 190-3은(는) 검색에 실패했습니다
# 경기도 고양시 관산동 190-4은(는) 검색에 실패했습니다
# 경기도 고양시 관산동 151-3은(는) 검색에 실패했습니다
# 경기도 고양시 고양동 240-6(255)은(는) 검색에 실패했습니다
# 경기도 고양시 토당동 352은(는) 검색에 실패했습니다
# 경기도 고양시 토당동 53-44은(는) 검색에 실패했습니다
# 경기도 고양시 사리현동 466-1은(는) 검색에 실패했습니다
# 경기도 고양시 토당동 37-14은(는) 검색에 실패했습니다
# 경기도 고양시 장항동 902은(는) 검색에 실패했습니다
# 경기도 고양시 장항동 881은(는) 검색에 실패했습니다
# 경기도 고양시 장항동 877은(는) 검색에 실패했습니다
# 경기도 고양시 장항동 875은(는) 검색에 실패했습니다
# 경기도 고양시 마두동 883은(는) 검색에 실패했습니다
# 경기도 고양시 토당동 24-0은(는) 검색에 실패했습니다
# 경기도 고양시 고양동 103은(는) 검색에 실패했습니다
# 경기도 고양시 장항동 1784은(는) 검색에 실패했습니다
# 실패건수 :  342
#    시군명      공동주택명정보    읍면동주소   지번주소     사용검사일자  층수  동수  세대수 의무관리대상여부  \
# 0  가평군        가평블루핀  가평읍 읍내리  766-3 2019-09-27  19   2  119        N
# 1  가평군       가평우림필유  가평읍 대곡리    360 2006-12-26  15   2  190        Y
# 2  가평군    가평읍내주공아파트  가평읍 읍내리    270 1999-11-19  12   5  355        N
# 3  가평군  가평읍내휴먼시아2단지  가평읍 읍내리    234 2010-08-30  13   6  335        N
# 4  가평군        가평코아루  가평읍 읍내리   1053 2021-11-09  20   3  221        Y
#
#                     addr                 x                 y
# 0  경기도 가평군 가평읍 읍내리 766-3  1000668.76528436  1981987.33999711
# 1    경기도 가평군 가평읍 대곡리 360  1000909.00806808   1980391.4678449
# 2    경기도 가평군 가평읍 읍내리 270  1001229.25097829   1981401.2528367
# 3    경기도 가평군 가평읍 읍내리 234  1001118.75742809  1981626.62844603
# 4   경기도 가평군 가평읍 읍내리 1053               NaN               NaN

# %%
#5 seoul university  ..# SGIS 좌표변환 API를 활용한 좌표변환 함수
def get_transcoord(src, dst, posX, posY) -> None:
    access_token = get_access_token(consumer_key, consumer_secret)
    url="https://sgisapi.kostat.go.kr/OpenAPI3/transformation/transcoord.json"
    params={
        "accessToken": access_token,
        "src": src, # 현재 좌표체계
        "dst": dst, # 변환할 좌표체계
        "posX": posX, # 변환할 좌표 X값
        "posY":	posY # 변환할 좌표 Y값
    }

    temp_dict = requests.get(
        url=url,
        params=params
    ).json()["result"]

    return temp_dict["posX"], temp_dict["posY"] # 변환된 좌표값 딕셔너리의 value 리턴

print('슝~')
# Out:
# 슝~

# %%
#5 seoul university  .. 좌표계가 UTM-K이므로 WSG84좌표계로 변환
for _, row in apt_df.iterrows():
    try:
        x, y = get_transcoord("EPSG:5179", "EPSG:4326", row["x"], row["y"])
    
        apt_df.loc[_, "lng"] = x
        apt_df.loc[_, "lat"] = y

    except:
        pass
apt_df.head()
# Out:
#    시군명      공동주택명정보    읍면동주소   지번주소     사용검사일자  층수  동수  세대수 의무관리대상여부  \
# 0  가평군        가평블루핀  가평읍 읍내리  766-3 2019-09-27  19   2  119        N
# 1  가평군       가평우림필유  가평읍 대곡리    360 2006-12-26  15   2  190        Y
# 2  가평군    가평읍내주공아파트  가평읍 읍내리    270 1999-11-19  12   5  355        N
# 3  가평군  가평읍내휴먼시아2단지  가평읍 읍내리    234 2010-08-30  13   6  335        N
# 4  가평군        가평코아루  가평읍 읍내리   1053 2021-11-09  20   3  221        Y
#
#                     addr                 x                 y         lng  \
# 0  경기도 가평군 가평읍 읍내리 766-3  1000668.76528436  1981987.33999711  127.507600
# 1    경기도 가평군 가평읍 대곡리 360  1000909.00806808   1980391.4678449  127.510329
# 2    경기도 가평군 가평읍 읍내리 270  1001229.25097829   1981401.2528367  127.513969
# 3    경기도 가평군 가평읍 읍내리 234  1001118.75742809  1981626.62844603  127.512714
# 4   경기도 가평군 가평읍 읍내리 1053               NaN               NaN         NaN
#
#          lat
# 0  37.837651
# 1  37.823267
# 2  37.832368
# 3  37.834400
# 4        NaN

# %%
#5 seoul university  .. 시각화 .. 초기 중심값 좌표가 들어가야 합니다.

# 서울시 중심부 위도, 경도
center = [37.541, 126.986]

# map이 서울 중심부에 위치하고, zoom 레벨은 12로 시작합니다.
map = folium.Map(
    location=center,
    zoom_start=12

)

print('슝~')
# Out:
# 슝~

# %%
# #5 seoul university # 대학 이름, 위도, 경도를 가져와 시각화
# for _, row in apt_df.iterrows():
#     try:
#         folium.Marker(
#             location=[row["lat"], row["lng"]], # 좌표
#             popup=row["공동주택명정보"], # 클릭시 표시될 popup 내용
#             icon=folium.Icon(color="cadetblue", icon="info-sign") # 표시될 아이콘 설정
#         ).add_to(map)
#     except:
#         pass

# print('슝~')
# Out:
# 슝~

# %%
#2. 프로젝트(1)  # MarkerCluster 객체 
marker_cluster = MarkerCluster().add_to(map)

#maker 객체 추가
for idx, row in apt_df.iterrows():
    try:
        folium.Marker(
            location=[apt_df.loc[idx, "lat"], apt_df.loc[idx, "lng"]],
            popup=apt_df.loc[idx, "공동주택명정보"],
            icon=folium.Icon(color="cadetblue", icon="house")            
        ).add_to(marker_cluster)
    except:
        pass

print('슝~')

# %%
#5 seoul university 
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_e552d85429c846fca5438bc7a801aa96%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_e552d85429c846fca5438bc7a801aa96%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_e552d85429c846fca5438bc7a801aa96%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_e552d85429c846fca5438bc7a801aa96%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.541%2C%20126.986%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
map.save("/aiffel/aiffel/0000_AIFFELTHON/3김연수/003_map_xml/apt_gapyeung.html")

# %%
apt_df.to_csv("apt_gapyeung.csv", index = False)
