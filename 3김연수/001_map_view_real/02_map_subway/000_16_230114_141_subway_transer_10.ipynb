# %% [markdown]
#     000_16_230114_141_subway_transer_07
#
#     data : 006_수도권6호선_주소데이터_20221122.csv
#      save : subway_info_10.csv
#      display : subway_info_10.html

# %%
#1. package load
import requests
import json
import os
import math
import time
import pandas as pd
import numpy as np
import geopandas as gpd
import folium
import matplotlib.pyplot as plt

from shapely.geometry import mapping, shape, Point, Polygon, LineString
from folium import plugins
from folium.plugins import MarkerCluster, HeatMap
print('슝~')
# Out:
# 슝~

# %%
#2. data load  ...SGIS data 가져오기 # SGIS API 사이트의 본인의 consumer_key, consumer_secret를 입력합니다.
consumer_key = '2f74504a63224ee09f2b'       # 서비스ID
consumer_secret =  '63a0ffef893e43a48ae2' # 보안Key

# %%
#2. data load  ... SGIS data 가져오기 # SGIS ACCESS TOKEN을 리턴 해주는 함수
def get_access_token(consumer_key, consumer_secret) -> None:
    temp_res = requests.get(
        url="https://sgisapi.kostat.go.kr/OpenAPI3/auth/authentication.json",
        params={
            "consumer_key": consumer_key,
            "consumer_secret": consumer_secret
        }
    )

    access_token = temp_res.json()["result"]["accessToken"]
   
    return access_token
print('슝~')
# Out:
# 슝~

# %%
#path = 'c:/Users/User/000_my_jupyter/900_aiffel/0000_AIFFELTHON/3김연수/002_data_dir/003_search_data/subway_addr/001_수도권1호선_주소데이터_20221122.csv'

subway_info_df = pd.read_csv('c:/Users/User/000_my_jupyter/900_aiffel/0000_AIFFELTHON/3김연수/002_data_dir/003_search_data/subway_addr/010_공항철도_주소데이터_20221122.csv',encoding='cp949')
subway_info_df.head()
# Out:
#     철도운영기관명    선명      역명                   지번주소  \
# 0  공항철도주식회사  공항철도      검암   인천광역시 서구 검암동 414-204
# 1  공항철도주식회사  공항철도      계양  인천광역시 계양구 귤현동 451-264
# 2  공항철도주식회사  공항철도      공덕    서울특별시 마포구 도화동 25-13
# 3  공항철도주식회사  공항철도  공항화물청사    인천광역시 중구 운서동 2844-7
# 4  공항철도주식회사  공항철도    김포공항      서울특별시 강서구 방화동 886
#
#                                  도로명주소
# 0      인천광역시 서구 검바위로 26 (검암동) 공항철도 검암역
# 1      인천광역시 계양구 다남로 24 (귤현동) 공항철도 계양역
# 2     서울특별시 마포구 마포대로  92(도화동) 공항철도 공덕역
# 3  인천광역시 중구 공항동로135번길 86 (운서동) 공항화물청사역
# 4    서울특별시 강서구 하늘길  77(방화동) 공항철도 김포공항역

# %%
subway_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   철도운영기관명  14 non-null     object
#  1   선명       14 non-null     object
#  2   역명       14 non-null     object
#  3   지번주소     14 non-null     object
#  4   도로명주소    14 non-null     object
# dtypes: object(5)
# memory usage: 688.0+ bytes

# %%
# subway_info_df['주소'] = subway_info_df['주소'].astype(str)

# %%
#5  university   # 주소를 입력해 주소의 위도, 경도를 가지고 오는 함수
def get_adress_x_y(address) -> None:
    # SGIS access_token 가져오기
    access_token = get_access_token(consumer_key , consumer_secret)

    url="https://sgisapi.kostat.go.kr/OpenAPI3/addr/geocode.json"
    params={
        "accessToken": access_token,
        "address": address
    }

    temp_res = requests.get(
        url=url,
        params=params
    ).json()["result"]["resultdata"]

    return temp_res[0]["x"], temp_res[0]["y"]

print('슝~')
# Out:
# 슝~

# %%
#5  university .. 주소 기반 위도,경도 추가
for _, row in subway_info_df.iterrows():
    try:
        x, y = get_adress_x_y(row["도로명주소"])
     
        subway_info_df.loc[_, "x"] = x
        subway_info_df.loc[_, "y"] = y
    except:
        print(row["도로명주소"] + '은(는) 검색에 실패했습니다')

subway_info_df.head()
# Out:
#     철도운영기관명    선명      역명                   지번주소  \
# 0  공항철도주식회사  공항철도      검암   인천광역시 서구 검암동 414-204
# 1  공항철도주식회사  공항철도      계양  인천광역시 계양구 귤현동 451-264
# 2  공항철도주식회사  공항철도      공덕    서울특별시 마포구 도화동 25-13
# 3  공항철도주식회사  공항철도  공항화물청사    인천광역시 중구 운서동 2844-7
# 4  공항철도주식회사  공항철도    김포공항      서울특별시 강서구 방화동 886
#
#                                  도로명주소                 x                 y
# 0      인천광역시 서구 검바위로 26 (검암동) 공항철도 검암역  927015.848873822  1952509.36139519
# 1      인천광역시 계양구 다남로 24 (귤현동) 공항철도 계양역   932508.34556226  1952732.32682826
# 2     서울특별시 마포구 마포대로  92(도화동) 공항철도 공덕역  951608.111997269    1949386.418051
# 3  인천광역시 중구 공항동로135번길 86 (운서동) 공항화물청사역  909568.714561091  1940473.95884906
# 4    서울특별시 강서구 하늘길  77(방화동) 공항철도 김포공항역   938290.91320417  1951668.90699964

# %%
#5  university  ..# SGIS 좌표변환 API를 활용한 좌표변환 함수
def get_transcoord(src, dst, posX, posY) -> None:
    access_token = get_access_token(consumer_key, consumer_secret)
    url="https://sgisapi.kostat.go.kr/OpenAPI3/transformation/transcoord.json"
    params={
        "accessToken": access_token,
        "src": src, # 현재 좌표체계
        "dst": dst, # 변환할 좌표체계
        "posX": posX, # 변환할 좌표 X값
        "posY":	posY # 변환할 좌표 Y값
    }

    temp_dict = requests.get(
        url=url,
        params=params
    ).json()["result"]

    return temp_dict["posX"], temp_dict["posY"] # 변환된 좌표값 딕셔너리의 value 리턴

print('슝~')
# Out:
# 슝~

# %%
#5  university  .. 좌표계가 UTM-K이므로 WSG84좌표계로 변환
for _, row in subway_info_df.iterrows():
    try:
        x, y = get_transcoord("EPSG:5179", "EPSG:4326", row["x"], row["y"])
    
        subway_info_df.loc[_, "lng"] = x
        subway_info_df.loc[_, "lat"] = y

    except:
        pass
subway_info_df.head()
# Out:
#     철도운영기관명    선명      역명                   지번주소  \
# 0  공항철도주식회사  공항철도      검암   인천광역시 서구 검암동 414-204
# 1  공항철도주식회사  공항철도      계양  인천광역시 계양구 귤현동 451-264
# 2  공항철도주식회사  공항철도      공덕    서울특별시 마포구 도화동 25-13
# 3  공항철도주식회사  공항철도  공항화물청사    인천광역시 중구 운서동 2844-7
# 4  공항철도주식회사  공항철도    김포공항      서울특별시 강서구 방화동 886
#
#                                  도로명주소                 x                 y  \
# 0      인천광역시 서구 검바위로 26 (검암동) 공항철도 검암역  927015.848873822  1952509.36139519
# 1      인천광역시 계양구 다남로 24 (귤현동) 공항철도 계양역   932508.34556226  1952732.32682826
# 2     서울특별시 마포구 마포대로  92(도화동) 공항철도 공덕역  951608.111997269    1949386.418051
# 3  인천광역시 중구 공항동로135번길 86 (운서동) 공항화물청사역  909568.714561091  1940473.95884906
# 4    서울특별시 강서구 하늘길  77(방화동) 공항철도 김포공항역   938290.91320417  1951668.90699964
#
#           lng        lat
# 0  126.673540  37.569063
# 1  126.735711  37.571492
# 2  126.952210  37.542537
# 3  126.477479  37.459049
# 4  126.801278  37.562313

# %%
#5  university  .. 시각화 .. 초기 중심값 좌표가 들어가야 합니다.

# 서울시 중심부 위도, 경도
center = [37.541, 126.986]

# map이 서울 중심부에 위치하고, zoom 레벨은 12로 시작합니다.
map = folium.Map(
    location=center,
    zoom_start=12

)

print('슝~')
# Out:
# 슝~

# %%
#2. 프로젝트(1)  # MarkerCluster 객체 
marker_cluster = MarkerCluster().add_to(map)

#maker 객체 추가
for idx, row in subway_info_df.iterrows():
    try:
        folium.Marker(
            location=[subway_info_df.loc[idx, "lat"], subway_info_df.loc[idx, "lng"]],
            popup=subway_info_df.loc[idx, "역명"],
            icon=folium.Icon(color="cadetblue", icon="flag")            
        ).add_to(marker_cluster)
    except:
        pass

print('슝~')
# Out:
# 슝~

# %%
#5 seoul university 
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_07bedb3a2af41f3a8d984fe89fcfe567 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_07bedb3a2af41f3a8d984fe89fcfe567&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_07bedb3a2af41f3a8d984fe89fcfe567 = L.map(
#                 &quot;map_07bedb3a2af41f3a8d984fe89fcfe567&quot;,
#                 {
#                     center: [37.541, 126.986],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b6cfa113c5868e7d83932dffc28772e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_07bedb3a2af41f3a8d984fe89fcfe567);
#
#
#             var marker_cluster_1da42621a103dc283c051198debead38 = L.markerClusterGroup(
#                 {}
#             );
#             map_07bedb3a2af41f3a8d984fe89fcfe567.addLayer(marker_cluster_1da42621a103dc283c051198debead38);
#
#
#             var marker_91b96bad1c1e737519eab096f0d7b021 = L.marker(
#                 [37.56906307798406, 126.67354035398814],
#                 {}
#             ).addTo(marker_cluster_1da42621a103dc283c051198debead38);
#
#
#             var icon_d5f96f3958e2049f617ccf126d59aedc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;flag&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_91b96bad1c1e737519eab096f0d7b021.setIcon(icon_d5f96f3958e2049f617ccf126d59aedc);
#
#
#         var popup_14051a6b00702dd5db401b83589a2869 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eba11fa5f5351f4e80f8f9c0bf5065d5 = $(`&lt;div id=&quot;html_eba11fa5f5351f4e80f8f9c0bf5065d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;검암&lt;/div&gt;`)[0];
#                 popup_14051a6b00702dd5db401b83589a2869.setContent(html_eba11fa5f5351f4e80f8f9c0bf5065d5);
#
#
#
#         marker_91b96bad1c1e737519eab096f0d7b021.bindPopup(popup_14051a6b00702dd5db401b83589a2869)
#         ;
#
#
#
#
#             var marker_622e9c036d0e2027c2a31055353f200a = L.marker(
#                 [37.571491622706226, 126.73571060547562],
#                 {}
#             ).addTo(marker_cluster_1da42621a103dc283c051198debead38);
#
#
#             var icon_edfd58948fec9b0c49c0be2bf4647437 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;flag&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_622e9c036d0e2027c2a31055353f200a.setIcon(icon_edfd58948fec9b0c49c0be2bf4647437);
#
#
#         var popup_39b2c477b60abe58eb71d5d40dbfc7f0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_95ede5c86369e08dc93254f97b0a7a0b = $(`&lt;div id=&quot;html_95ede5c86369e08dc93254f97b0a7a0b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;계양&lt;/div&gt;`)[0];
#                 popup_39b2c477b60abe58eb71d5d40dbfc7f0.setContent(html_95ede5c86369e08dc93254f97b0a7a0b);
#
#
#
#         marker_622e9c036d0e2027c2a31055353f200a.bindPopup(popup_39b2c477b60abe58eb71d5d40dbfc7f0)
#         ;
#
#
#
#
#             var marker_49b3f42c23d22d0c034963f7d0e2826f = L.marker(
#                 [37.54253653104963, 126.9522102569884],
#                 {}
#             ).addTo(marker_cluster_1da42621a103dc283c051198debead38);
#
#
#             var icon_6058758e5b071e9cd771cde93641ee26 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;flag&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_49b3f42c23d22d0c034963f7d0e2826f.setIcon(icon_6058758e5b071e9cd771cde93641ee26);
#
#
#         var popup_7597771796de2d3033f97d7bb6eb2882 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ed3b5871d08288d0b5573e6d3520fdea = $(`&lt;div id=&quot;html_ed3b5871

# %%
map.save("c:/Users/User/000_my_jupyter/900_aiffel/0000_AIFFELTHON/3김연수/003_map_xml/subway_info_10.html")

# %%
#apt_df.to_excel("C:/Users/User/000_my_jupyter/900_aiffel/0000_AIFFELTHON/data/apt_cn_sung.xls", index = False)
# subway_info_df.to_csv("c:/Users/User/000_my_jupyter/900_aiffel/0000_AIFFELTHON/3김연수/002_data_dir/003_search_data/subway_info_02.csv", index = False)
subway_info_df.to_csv("subway_info_10.csv", index = False)
