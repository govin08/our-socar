# %% [markdown]
#     000_16_230114_141_subway_transer_26
#
#     data :026_에버라인_주소데이터_20221122.csv'
#      save : subway_info_26.csv
#      display : subway_info_26.html

# %%
#1. package load
import requests
import json
import os
import math
import time
import pandas as pd
import numpy as np
import geopandas as gpd
import folium
import matplotlib.pyplot as plt

from shapely.geometry import mapping, shape, Point, Polygon, LineString
from folium import plugins
from folium.plugins import MarkerCluster, HeatMap
print('슝~')
# Out:
# 슝~

# %%
#2. data load  ...SGIS data 가져오기 # SGIS API 사이트의 본인의 consumer_key, consumer_secret를 입력합니다.
consumer_key = '2f74504a63224ee09f2b'       # 서비스ID
consumer_secret =  '63a0ffef893e43a48ae2' # 보안Key

# %%
#2. data load  ... SGIS data 가져오기 # SGIS ACCESS TOKEN을 리턴 해주는 함수
def get_access_token(consumer_key, consumer_secret) -> None:
    temp_res = requests.get(
        url="https://sgisapi.kostat.go.kr/OpenAPI3/auth/authentication.json",
        params={
            "consumer_key": consumer_key,
            "consumer_secret": consumer_secret
        }
    )

    access_token = temp_res.json()["result"]["accessToken"]
   
    return access_token
print('슝~')
# Out:
# 슝~

# %%
#path = 'c:/Users/User/000_my_jupyter/900_aiffel/0000_AIFFELTHON/3김연수/002_data_dir/003_search_data/subway_addr/001_수도권1호선_주소데이터_20221122.csv'

subway_info_df = pd.read_csv('c:/Users/User/000_my_jupyter/900_aiffel/0000_AIFFELTHON/3김연수/002_data_dir/003_search_data/subway_addr/026_에버라인_주소데이터_20221122.csv',encoding='cp949')
subway_info_df.head()
# Out:
#       철도운영기관명      선명           역명                     지번주소  \
# 0  용인경량전철주식회사  용인에버라인          강남대   경기도 용인시 기흥구 구갈동 480-42
# 1  용인경량전철주식회사  용인에버라인           고진   경기도 용인시 처인구 유방동 1029-8
# 2  용인경량전철주식회사  용인에버라인  기흥(백남준아트센터)   경기도 용인시 기흥구 구갈동 480-36
# 3  용인경량전철주식회사  용인에버라인          김량장  경기도 용인시 처인구 김량장동 486-21
# 4  용인경량전철주식회사  용인에버라인           동백      경기도 용인시 기흥구 중동 1087
#
#                     도로명주소
# 0    경기도 용인시 기흥구 중부대로 578
# 1    경기도 용인시 처인구 경안천로 141
# 2    경기도 용인시 기흥구 중부대로 460
# 3     경기도 용인시 처인구 금학로 315
# 4  경기도 용인시 기흥구 동백죽전대로 314

# %%
subway_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   철도운영기관명  15 non-null     object
#  1   선명       15 non-null     object
#  2   역명       15 non-null     object
#  3   지번주소     15 non-null     object
#  4   도로명주소    15 non-null     object
# dtypes: object(5)
# memory usage: 728.0+ bytes

# %%
# subway_info_df['주소'] = subway_info_df['주소'].astype(str)

# %%
#5  university   # 주소를 입력해 주소의 위도, 경도를 가지고 오는 함수
def get_adress_x_y(address) -> None:
    # SGIS access_token 가져오기
    access_token = get_access_token(consumer_key , consumer_secret)

    url="https://sgisapi.kostat.go.kr/OpenAPI3/addr/geocode.json"
    params={
        "accessToken": access_token,
        "address": address
    }

    temp_res = requests.get(
        url=url,
        params=params
    ).json()["result"]["resultdata"]

    return temp_res[0]["x"], temp_res[0]["y"]

print('슝~')
# Out:
# 슝~

# %%
#5  university .. 주소 기반 위도,경도 추가
for _, row in subway_info_df.iterrows():
    try:
        x, y = get_adress_x_y(row["도로명주소"])
     
        subway_info_df.loc[_, "x"] = x
        subway_info_df.loc[_, "y"] = y
    except:
        print(row["도로명주소"] + '은(는) 검색에 실패했습니다')

subway_info_df.head()
# Out:
#       철도운영기관명      선명           역명                     지번주소  \
# 0  용인경량전철주식회사  용인에버라인          강남대   경기도 용인시 기흥구 구갈동 480-42
# 1  용인경량전철주식회사  용인에버라인           고진   경기도 용인시 처인구 유방동 1029-8
# 2  용인경량전철주식회사  용인에버라인  기흥(백남준아트센터)   경기도 용인시 기흥구 구갈동 480-36
# 3  용인경량전철주식회사  용인에버라인          김량장  경기도 용인시 처인구 김량장동 486-21
# 4  용인경량전철주식회사  용인에버라인           동백      경기도 용인시 기흥구 중동 1087
#
#                     도로명주소                 x                 y
# 0    경기도 용인시 기흥구 중부대로 578  966846.681545387  1919090.39185825
# 1    경기도 용인시 처인구 경안천로 141  974650.634324306  1916235.15986188
# 2    경기도 용인시 기흥구 중부대로 460  965952.716155913  1919710.17941791
# 3     경기도 용인시 처인구 금학로 315  973275.165761939  1915425.23711486
# 4  경기도 용인시 기흥구 동백죽전대로 314  969213.024562001  1918972.75039051

# %%
#5  university  ..# SGIS 좌표변환 API를 활용한 좌표변환 함수
def get_transcoord(src, dst, posX, posY) -> None:
    access_token = get_access_token(consumer_key, consumer_secret)
    url="https://sgisapi.kostat.go.kr/OpenAPI3/transformation/transcoord.json"
    params={
        "accessToken": access_token,
        "src": src, # 현재 좌표체계
        "dst": dst, # 변환할 좌표체계
        "posX": posX, # 변환할 좌표 X값
        "posY":	posY # 변환할 좌표 Y값
    }

    temp_dict = requests.get(
        url=url,
        params=params
    ).json()["result"]

    return temp_dict["posX"], temp_dict["posY"] # 변환된 좌표값 딕셔너리의 value 리턴

print('슝~')
# Out:
# 슝~

# %%
#5  university  .. 좌표계가 UTM-K이므로 WSG84좌표계로 변환
for _, row in subway_info_df.iterrows():
    try:
        x, y = get_transcoord("EPSG:5179", "EPSG:4326", row["x"], row["y"])
    
        subway_info_df.loc[_, "lng"] = x
        subway_info_df.loc[_, "lat"] = y

    except:
        pass
subway_info_df.head()
# Out:
#       철도운영기관명      선명           역명                     지번주소  \
# 0  용인경량전철주식회사  용인에버라인          강남대   경기도 용인시 기흥구 구갈동 480-42
# 1  용인경량전철주식회사  용인에버라인           고진   경기도 용인시 처인구 유방동 1029-8
# 2  용인경량전철주식회사  용인에버라인  기흥(백남준아트센터)   경기도 용인시 기흥구 구갈동 480-36
# 3  용인경량전철주식회사  용인에버라인          김량장  경기도 용인시 처인구 김량장동 486-21
# 4  용인경량전철주식회사  용인에버라인           동백      경기도 용인시 기흥구 중동 1087
#
#                     도로명주소                 x                 y         lng  \
# 0    경기도 용인시 기흥구 중부대로 578  966846.681545387  1919090.39185825  127.126064
# 1    경기도 용인시 처인구 경안천로 141  974650.634324306  1916235.15986188  127.214181
# 2    경기도 용인시 기흥구 중부대로 460  965952.716155913  1919710.17941791  127.115953
# 3     경기도 용인시 처인구 금학로 315  973275.165761939  1915425.23711486  127.198702
# 4  경기도 용인시 기흥구 동백죽전대로 314  969213.024562001  1918972.75039051  127.152759
#
#          lat
# 0  37.270134
# 1  37.244642
# 2  37.275688
# 3  37.237303
# 4  37.269155

# %%
#5  university  .. 시각화 .. 초기 중심값 좌표가 들어가야 합니다.

# 서울시 중심부 위도, 경도
center = [37.541, 126.986]

# map이 서울 중심부에 위치하고, zoom 레벨은 12로 시작합니다.
map = folium.Map(
    location=center,
    zoom_start=12

)

print('슝~')
# Out:
# 슝~

# %%
#2. 프로젝트(1)  # MarkerCluster 객체 
marker_cluster = MarkerCluster().add_to(map)

#maker 객체 추가
for idx, row in subway_info_df.iterrows():
    try:
        folium.Marker(
            location=[subway_info_df.loc[idx, "lat"], subway_info_df.loc[idx, "lng"]],
            popup=subway_info_df.loc[idx, "역명"],
            icon=folium.Icon(color="cadetblue", icon="flag")            
        ).add_to(marker_cluster)
    except:
        pass

print('슝~')
# Out:
# 슝~

# %%
#5 seoul university 
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e9829178cf7af401745c1088e9943821 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e9829178cf7af401745c1088e9943821&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e9829178cf7af401745c1088e9943821 = L.map(
#                 &quot;map_e9829178cf7af401745c1088e9943821&quot;,
#                 {
#                     center: [37.541, 126.986],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_14dca9ece209d5e331f0152cbb4948b9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e9829178cf7af401745c1088e9943821);
#
#
#             var marker_cluster_7e9651913b15108555c5ee80527b2d74 = L.markerClusterGroup(
#                 {}
#             );
#             map_e9829178cf7af401745c1088e9943821.addLayer(marker_cluster_7e9651913b15108555c5ee80527b2d74);
#
#
#             var marker_a58dc001bd45190f8b7bd1e738fb5945 = L.marker(
#                 [37.270133992330315, 127.12606432110019],
#                 {}
#             ).addTo(marker_cluster_7e9651913b15108555c5ee80527b2d74);
#
#
#             var icon_27503c7cf837a9a72956435526640676 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;flag&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a58dc001bd45190f8b7bd1e738fb5945.setIcon(icon_27503c7cf837a9a72956435526640676);
#
#
#         var popup_ca40069d86d43922226287c41e9c0edc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_57a3c4357f8ed74f33cd91749e554ceb = $(`&lt;div id=&quot;html_57a3c4357f8ed74f33cd91749e554ceb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강남대&lt;/div&gt;`)[0];
#                 popup_ca40069d86d43922226287c41e9c0edc.setContent(html_57a3c4357f8ed74f33cd91749e554ceb);
#
#
#
#         marker_a58dc001bd45190f8b7bd1e738fb5945.bindPopup(popup_ca40069d86d43922226287c41e9c0edc)
#         ;
#
#
#
#
#             var marker_6a389b40c65cead377e8ff6dff09a52a = L.marker(
#                 [37.2446424433078, 127.21418106582911],
#                 {}
#             ).addTo(marker_cluster_7e9651913b15108555c5ee80527b2d74);
#
#
#             var icon_17da5c6c2f9421c5c351fda40def911f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;flag&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6a389b40c65cead377e8ff6dff09a52a.setIcon(icon_17da5c6c2f9421c5c351fda40def911f);
#
#
#         var popup_5534332b49d054e5d5af0bb80a52baae = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c6e2442d314d3ae8ab3c022ff8f2f3c3 = $(`&lt;div id=&quot;html_c6e2442d314d3ae8ab3c022ff8f2f3c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;고진&lt;/div&gt;`)[0];
#                 popup_5534332b49d054e5d5af0bb80a52baae.setContent(html_c6e2442d314d3ae8ab3c022ff8f2f3c3);
#
#
#
#         marker_6a389b40c65cead377e8ff6dff09a52a.bindPopup(popup_5534332b49d054e5d5af0bb80a52baae)
#         ;
#
#
#
#
#             var marker_63a957ab2bcbc85a901c4202830ec58a = L.marker(
#                 [37.275688363088165, 127.1159531287095],
#                 {}
#             ).addTo(marker_cluster_7e9651913b15108555c5ee80527b2d74);
#
#
#             var icon_05f8dfcec34d58cd161896a1b529aff2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;flag&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_63a957ab2bcbc85a901c4202830ec58a.setIcon(icon_05f8dfcec34d58cd161896a1b529aff2);
#
#
#         var popup_29d07295a1d7a1f3121247d485a50fb1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_23923e8f9867ab7109a5d3b0cda4b27b = $(`&lt;div id=&quot;html_23923e8

# %%
map.save("c:/Users/User/000_my_jupyter/900_aiffel/0000_AIFFELTHON/3김연수/003_map_xml/subway_info_26.html")

# %%
#apt_df.to_excel("C:/Users/User/000_my_jupyter/900_aiffel/0000_AIFFELTHON/data/apt_cn_sung.xls", index = False)
# subway_info_df.to_csv("c:/Users/User/000_my_jupyter/900_aiffel/0000_AIFFELTHON/3김연수/002_data_dir/003_search_data/subway_info_02.csv", index = False)
subway_info_df.to_csv("subway_info_26.csv", index = False)
