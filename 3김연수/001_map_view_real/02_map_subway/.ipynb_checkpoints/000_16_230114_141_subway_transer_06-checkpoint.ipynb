# %% [markdown]
#     000_16_230114_141_subway_transer_01
#
#     data : 006_수도권6호선_주소데이터_20221122.csv
#      save : subway_info_06.csv
#      display : subway_info_06.html

# %%
#1. package load
import requests
import json
import os
import math
import time
import pandas as pd
import numpy as np
import geopandas as gpd
import folium
import matplotlib.pyplot as plt

from shapely.geometry import mapping, shape, Point, Polygon, LineString
from folium import plugins
from folium.plugins import MarkerCluster, HeatMap
print('슝~')
# Out:
# 슝~

# %%
#2. data load  ...SGIS data 가져오기 # SGIS API 사이트의 본인의 consumer_key, consumer_secret를 입력합니다.
consumer_key = '2f74504a63224ee09f2b'       # 서비스ID
consumer_secret =  '63a0ffef893e43a48ae2' # 보안Key

# %%
#2. data load  ... SGIS data 가져오기 # SGIS ACCESS TOKEN을 리턴 해주는 함수
def get_access_token(consumer_key, consumer_secret) -> None:
    temp_res = requests.get(
        url="https://sgisapi.kostat.go.kr/OpenAPI3/auth/authentication.json",
        params={
            "consumer_key": consumer_key,
            "consumer_secret": consumer_secret
        }
    )

    access_token = temp_res.json()["result"]["accessToken"]
   
    return access_token
print('슝~')
# Out:
# 슝~

# %%
#path = 'c:/Users/User/000_my_jupyter/900_aiffel/0000_AIFFELTHON/3김연수/002_data_dir/003_search_data/subway_addr/001_수도권1호선_주소데이터_20221122.csv'

subway_info_df = pd.read_csv('c:/Users/User/000_my_jupyter/900_aiffel/0000_AIFFELTHON/3김연수/002_data_dir/003_search_data/subway_addr/006_수도권6호선_주소데이터_20221122.csv',encoding='cp949')
subway_info_df.head()
# Out:
#   철도운영기관명   선명         역명                            지번주소  \
# 0  서울교통공사  6호선    고려대(종암)   서울특별시 성북구 종암동 29-18 고려대역(6호선)
# 1  서울교통공사  6호선         공덕      서울특별시 마포구 공덕동 439 공덕역(6호선)
# 2  서울교통공사  6호선    광흥창(서강)  서울특별시 마포구 창전동 145-17 광흥창역(6호선)
# 3  서울교통공사  6호선         구산        서울특별시 은평구 구산동 1 구산역(6호선)
# 4  서울교통공사  6호선  녹사평(용산구청)     서울특별시 용산구 용산동4가 4 녹사평역(6호선)
#
#                         도로명주소
# 0        서울특별시 성북구 종암로 1(종암동)
# 1      서울특별시 마포구 백범로 200(공덕동)
# 2      서울특별시 마포구 독막로 165(창전동)
# 3    서울특별시 은평구 연서로 137-1(구산동)
# 4  서울특별시 용산구 녹사평대로 195(용산동4가)

# %%
subway_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   철도운영기관명  39 non-null     object
#  1   선명       39 non-null     object
#  2   역명       39 non-null     object
#  3   지번주소     39 non-null     object
#  4   도로명주소    39 non-null     object
# dtypes: object(5)
# memory usage: 1.6+ KB

# %%
# subway_info_df['주소'] = subway_info_df['주소'].astype(str)

# %%
#5  university   # 주소를 입력해 주소의 위도, 경도를 가지고 오는 함수
def get_adress_x_y(address) -> None:
    # SGIS access_token 가져오기
    access_token = get_access_token(consumer_key , consumer_secret)

    url="https://sgisapi.kostat.go.kr/OpenAPI3/addr/geocode.json"
    params={
        "accessToken": access_token,
        "address": address
    }

    temp_res = requests.get(
        url=url,
        params=params
    ).json()["result"]["resultdata"]

    return temp_res[0]["x"], temp_res[0]["y"]

print('슝~')
# Out:
# 슝~

# %%
#5  university .. 주소 기반 위도,경도 추가
for _, row in subway_info_df.iterrows():
    try:
        x, y = get_adress_x_y(row["도로명주소"])
     
        subway_info_df.loc[_, "x"] = x
        subway_info_df.loc[_, "y"] = y
    except:
        print(row["도로명주소"] + '은(는) 검색에 실패했습니다')

subway_info_df.head()
# Out:
#   철도운영기관명   선명         역명                            지번주소  \
# 0  서울교통공사  6호선    고려대(종암)   서울특별시 성북구 종암동 29-18 고려대역(6호선)
# 1  서울교통공사  6호선         공덕      서울특별시 마포구 공덕동 439 공덕역(6호선)
# 2  서울교통공사  6호선    광흥창(서강)  서울특별시 마포구 창전동 145-17 광흥창역(6호선)
# 3  서울교통공사  6호선         구산        서울특별시 은평구 구산동 1 구산역(6호선)
# 4  서울교통공사  6호선  녹사평(용산구청)     서울특별시 용산구 용산동4가 4 녹사평역(6호선)
#
#                         도로명주소                 x                 y
# 0        서울특별시 성북구 종암로 1(종암동)  959065.552922815  1954716.68945641
# 1      서울특별시 마포구 백범로 200(공덕동)  951588.346643768   1949494.5998432
# 2      서울특별시 마포구 독막로 165(창전동)   949821.49988041  1949945.87848504
# 3    서울특별시 은평구 연서로 137-1(구산동)  948560.985627863  1957024.32001003
# 4  서울특별시 용산구 녹사평대로 195(용산동4가)  954679.387255336  1948514.04629827

# %%
#5  university  ..# SGIS 좌표변환 API를 활용한 좌표변환 함수
def get_transcoord(src, dst, posX, posY) -> None:
    access_token = get_access_token(consumer_key, consumer_secret)
    url="https://sgisapi.kostat.go.kr/OpenAPI3/transformation/transcoord.json"
    params={
        "accessToken": access_token,
        "src": src, # 현재 좌표체계
        "dst": dst, # 변환할 좌표체계
        "posX": posX, # 변환할 좌표 X값
        "posY":	posY # 변환할 좌표 Y값
    }

    temp_dict = requests.get(
        url=url,
        params=params
    ).json()["result"]

    return temp_dict["posX"], temp_dict["posY"] # 변환된 좌표값 딕셔너리의 value 리턴

print('슝~')
# Out:
# 슝~

# %%
#5  university  .. 좌표계가 UTM-K이므로 WSG84좌표계로 변환
for _, row in subway_info_df.iterrows():
    try:
        x, y = get_transcoord("EPSG:5179", "EPSG:4326", row["x"], row["y"])
    
        subway_info_df.loc[_, "lng"] = x
        subway_info_df.loc[_, "lat"] = y

    except:
        pass
subway_info_df.head()
# Out:
#   철도운영기관명   선명         역명                            지번주소  \
# 0  서울교통공사  6호선    고려대(종암)   서울특별시 성북구 종암동 29-18 고려대역(6호선)
# 1  서울교통공사  6호선         공덕      서울특별시 마포구 공덕동 439 공덕역(6호선)
# 2  서울교통공사  6호선    광흥창(서강)  서울특별시 마포구 창전동 145-17 광흥창역(6호선)
# 3  서울교통공사  6호선         구산        서울특별시 은평구 구산동 1 구산역(6호선)
# 4  서울교통공사  6호선  녹사평(용산구청)     서울특별시 용산구 용산동4가 4 녹사평역(6호선)
#
#                         도로명주소                 x                 y         lng  \
# 0        서울특별시 성북구 종암로 1(종암동)  959065.552922815  1954716.68945641  127.036327
# 1      서울특별시 마포구 백범로 200(공덕동)  951588.346643768   1949494.5998432  126.951979
# 2      서울특별시 마포구 독막로 165(창전동)   949821.49988041  1949945.87848504  126.931949
# 3    서울특별시 은평구 연서로 137-1(구산동)  948560.985627863  1957024.32001003  126.917182
# 4  서울특별시 용산구 녹사평대로 195(용산동4가)  954679.387255336  1948514.04629827  126.987029
#
#          lat
# 0  37.590941
# 1  37.543511
# 2  37.547483
# 3  37.611213
# 4  37.534830

# %%
#5  university  .. 시각화 .. 초기 중심값 좌표가 들어가야 합니다.

# 서울시 중심부 위도, 경도
center = [37.541, 126.986]

# map이 서울 중심부에 위치하고, zoom 레벨은 12로 시작합니다.
map = folium.Map(
    location=center,
    zoom_start=12

)

print('슝~')
# Out:
# 슝~

# %%
#2. 프로젝트(1)  # MarkerCluster 객체 
marker_cluster = MarkerCluster().add_to(map)

#maker 객체 추가
for idx, row in subway_info_df.iterrows():
    try:
        folium.Marker(
            location=[subway_info_df.loc[idx, "lat"], subway_info_df.loc[idx, "lng"]],
            popup=subway_info_df.loc[idx, "역명"],
            icon=folium.Icon(color="cadetblue", icon="flag")            
        ).add_to(marker_cluster)
    except:
        pass

print('슝~')
# Out:
# 슝~

# %%
#5 seoul university 
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_432dd1f893be0b8d61bdf7a38bd124fd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_432dd1f893be0b8d61bdf7a38bd124fd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_432dd1f893be0b8d61bdf7a38bd124fd = L.map(
#                 &quot;map_432dd1f893be0b8d61bdf7a38bd124fd&quot;,
#                 {
#                     center: [37.541, 126.986],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1e7d71917a66cdbc3bb812f73879280b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_432dd1f893be0b8d61bdf7a38bd124fd);
#
#
#             var marker_cluster_f6ac1ab9b49e2eb96ba64a616d46e82c = L.markerClusterGroup(
#                 {}
#             );
#             map_432dd1f893be0b8d61bdf7a38bd124fd.addLayer(marker_cluster_f6ac1ab9b49e2eb96ba64a616d46e82c);
#
#
#             var marker_d34a55938692b602d153aaf42b78c7c5 = L.marker(
#                 [37.590941126030124, 127.03632703328923],
#                 {}
#             ).addTo(marker_cluster_f6ac1ab9b49e2eb96ba64a616d46e82c);
#
#
#             var icon_6af1a607a3a8d6f4143ccb1d47082ddf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;flag&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d34a55938692b602d153aaf42b78c7c5.setIcon(icon_6af1a607a3a8d6f4143ccb1d47082ddf);
#
#
#         var popup_76a55149be01ddd6430d93d412da1508 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ed60766ad71fcdc2522a7ad73abec9b4 = $(`&lt;div id=&quot;html_ed60766ad71fcdc2522a7ad73abec9b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;고려대(종암)&lt;/div&gt;`)[0];
#                 popup_76a55149be01ddd6430d93d412da1508.setContent(html_ed60766ad71fcdc2522a7ad73abec9b4);
#
#
#
#         marker_d34a55938692b602d153aaf42b78c7c5.bindPopup(popup_76a55149be01ddd6430d93d412da1508)
#         ;
#
#
#
#
#             var marker_646aa9b37b5441729d5e49a9892b162e = L.marker(
#                 [37.54351055571775, 126.95197938783994],
#                 {}
#             ).addTo(marker_cluster_f6ac1ab9b49e2eb96ba64a616d46e82c);
#
#
#             var icon_e1cb4e19856c218e05b0f5c7cc21464a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;flag&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_646aa9b37b5441729d5e49a9892b162e.setIcon(icon_e1cb4e19856c218e05b0f5c7cc21464a);
#
#
#         var popup_e5d0e87a61f413a0f86762c453aab27c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b6b79b7d24154c7f8dfebbd25a6906fe = $(`&lt;div id=&quot;html_b6b79b7d24154c7f8dfebbd25a6906fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;공덕&lt;/div&gt;`)[0];
#                 popup_e5d0e87a61f413a0f86762c453aab27c.setContent(html_b6b79b7d24154c7f8dfebbd25a6906fe);
#
#
#
#         marker_646aa9b37b5441729d5e49a9892b162e.bindPopup(popup_e5d0e87a61f413a0f86762c453aab27c)
#         ;
#
#
#
#
#             var marker_55dd6ff603e95f45750fd00d0883c483 = L.marker(
#                 [37.54748348563546, 126.93194867792941],
#                 {}
#             ).addTo(marker_cluster_f6ac1ab9b49e2eb96ba64a616d46e82c);
#
#
#             var icon_d9f661e60c86a0d10a81461527d74eb5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;flag&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_55dd6ff603e95f45750fd00d0883c483.setIcon(icon_d9f661e60c86a0d10a81461527d74eb5);
#
#
#         var popup_0edb671e72cdbc07f0fa397408eccc79 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d80599719d4cec9de109e9ceee54ddcb = $(`&lt;div id=&quot;html_d8

# %%
map.save("c:/Users/User/000_my_jupyter/900_aiffel/0000_AIFFELTHON/3김연수/003_map_xml/subway_info_06.html")

# %%
#apt_df.to_excel("C:/Users/User/000_my_jupyter/900_aiffel/0000_AIFFELTHON/data/apt_cn_sung.xls", index = False)
# subway_info_df.to_csv("c:/Users/User/000_my_jupyter/900_aiffel/0000_AIFFELTHON/3김연수/002_data_dir/003_search_data/subway_info_02.csv", index = False)
subway_info_df.to_csv("subway_info_06.csv", index = False)
