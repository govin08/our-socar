# %% [markdown]
#     000_16_230114_141_subway_transer_07
#
#    data : 008_수도권8호선_주소데이터_20221122.csv
#      save : subway_info_08.csv
#      display : subway_info_08.html

# %%
#1. package load
import requests
import json
import os
import math
import time
import pandas as pd
import numpy as np
import geopandas as gpd
import folium
import matplotlib.pyplot as plt

from shapely.geometry import mapping, shape, Point, Polygon, LineString
from folium import plugins
from folium.plugins import MarkerCluster, HeatMap
print('슝~')
# Out:
# 슝~

# %%
#2. data load  ...SGIS data 가져오기 # SGIS API 사이트의 본인의 consumer_key, consumer_secret를 입력합니다.
consumer_key = '2f74504a63224ee09f2b'       # 서비스ID
consumer_secret =  '63a0ffef893e43a48ae2' # 보안Key

# %%
#2. data load  ... SGIS data 가져오기 # SGIS ACCESS TOKEN을 리턴 해주는 함수
def get_access_token(consumer_key, consumer_secret) -> None:
    temp_res = requests.get(
        url="https://sgisapi.kostat.go.kr/OpenAPI3/auth/authentication.json",
        params={
            "consumer_key": consumer_key,
            "consumer_secret": consumer_secret
        }
    )

    access_token = temp_res.json()["result"]["accessToken"]
   
    return access_token
print('슝~')
# Out:
# 슝~

# %%
#path = 'c:/Users/User/000_my_jupyter/900_aiffel/0000_AIFFELTHON/3김연수/002_data_dir/003_search_data/subway_addr/001_수도권1호선_주소데이터_20221122.csv'

subway_info_df = pd.read_csv('c:/Users/User/000_my_jupyter/900_aiffel/0000_AIFFELTHON/3김연수/002_data_dir/003_search_data/subway_addr/008_수도권8호선_주소데이터_20221122.csv',encoding='cp949')
subway_info_df.head()
# Out:
#   철도운영기관명   선명                역명                              지번주소  \
# 0  서울교통공사  8호선              가락시장   서울특별시 송파구 가락동 184-23 가락시장역(8호선)
# 1  서울교통공사  8호선              강동구청      서울특별시 강동구 성내동 319 강동구청역(8호선)
# 2  서울교통공사  8호선               남위례      경기도 성남시 수정구 복정동 57 남위례역(8호선)
# 3  서울교통공사  8호선  남한산성입구(성남법원·검찰청)   경기도 성남시 수정구 단대동 96 남한산성입구역(8호선)
# 4  서울교통공사  8호선             단대오거리  경기도 성남시 수정구 신흥동 2467 단대오거리역(8호선)
#
#                        도로명주소
# 0    서울특별시 송파구 송파대로 257(가락동)
# 1    서울특별시 강동구 올림픽로 550(성내동)
# 2   경기도 성남시 수정구 공원로 601(복정동)
# 3  경기도 성남시 수정구 산성대로 445(단대동)
# 4  경기도 성남시 수정구 산성대로 365(신흥동)

# %%
subway_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   철도운영기관명  18 non-null     object
#  1   선명       18 non-null     object
#  2   역명       18 non-null     object
#  3   지번주소     18 non-null     object
#  4   도로명주소    18 non-null     object
# dtypes: object(5)
# memory usage: 848.0+ bytes

# %%
# subway_info_df['주소'] = subway_info_df['주소'].astype(str)

# %%
#5  university   # 주소를 입력해 주소의 위도, 경도를 가지고 오는 함수
def get_adress_x_y(address) -> None:
    # SGIS access_token 가져오기
    access_token = get_access_token(consumer_key , consumer_secret)

    url="https://sgisapi.kostat.go.kr/OpenAPI3/addr/geocode.json"
    params={
        "accessToken": access_token,
        "address": address
    }

    temp_res = requests.get(
        url=url,
        params=params
    ).json()["result"]["resultdata"]

    return temp_res[0]["x"], temp_res[0]["y"]

print('슝~')
# Out:
# 슝~

# %%
#5  university .. 주소 기반 위도,경도 추가
for _, row in subway_info_df.iterrows():
    try:
        x, y = get_adress_x_y(row["도로명주소"])
     
        subway_info_df.loc[_, "x"] = x
        subway_info_df.loc[_, "y"] = y
    except:
        print(row["도로명주소"] + '은(는) 검색에 실패했습니다')

subway_info_df.head()
# Out:
#   철도운영기관명   선명                역명                              지번주소  \
# 0  서울교통공사  8호선              가락시장   서울특별시 송파구 가락동 184-23 가락시장역(8호선)
# 1  서울교통공사  8호선              강동구청      서울특별시 강동구 성내동 319 강동구청역(8호선)
# 2  서울교통공사  8호선               남위례      경기도 성남시 수정구 복정동 57 남위례역(8호선)
# 3  서울교통공사  8호선  남한산성입구(성남법원·검찰청)   경기도 성남시 수정구 단대동 96 남한산성입구역(8호선)
# 4  서울교통공사  8호선             단대오거리  경기도 성남시 수정구 신흥동 2467 단대오거리역(8호선)
#
#                        도로명주소                 x                 y
# 0    서울특별시 송파구 송파대로 257(가락동)  966274.643182304  1943789.80882922
# 1    서울특별시 강동구 올림픽로 550(성내동)  966476.463850377  1947997.66836326
# 2   경기도 성남시 수정구 공원로 601(복정동)  968101.715614944  1940492.23585887
# 3  경기도 성남시 수정구 산성대로 445(단대동)  969879.995846025  1939212.00958787
# 4  경기도 성남시 수정구 산성대로 365(신흥동)  969616.750438634  1938475.47499339

# %%
#5  university  ..# SGIS 좌표변환 API를 활용한 좌표변환 함수
def get_transcoord(src, dst, posX, posY) -> None:
    access_token = get_access_token(consumer_key, consumer_secret)
    url="https://sgisapi.kostat.go.kr/OpenAPI3/transformation/transcoord.json"
    params={
        "accessToken": access_token,
        "src": src, # 현재 좌표체계
        "dst": dst, # 변환할 좌표체계
        "posX": posX, # 변환할 좌표 X값
        "posY":	posY # 변환할 좌표 Y값
    }

    temp_dict = requests.get(
        url=url,
        params=params
    ).json()["result"]

    return temp_dict["posX"], temp_dict["posY"] # 변환된 좌표값 딕셔너리의 value 리턴

print('슝~')
# Out:
# 슝~

# %%
#5  university  .. 좌표계가 UTM-K이므로 WSG84좌표계로 변환
for _, row in subway_info_df.iterrows():
    try:
        x, y = get_transcoord("EPSG:5179", "EPSG:4326", row["x"], row["y"])
    
        subway_info_df.loc[_, "lng"] = x
        subway_info_df.loc[_, "lat"] = y

    except:
        pass
subway_info_df.head()
# Out:
#   철도운영기관명   선명                역명                              지번주소  \
# 0  서울교통공사  8호선              가락시장   서울특별시 송파구 가락동 184-23 가락시장역(8호선)
# 1  서울교통공사  8호선              강동구청      서울특별시 강동구 성내동 319 강동구청역(8호선)
# 2  서울교통공사  8호선               남위례      경기도 성남시 수정구 복정동 57 남위례역(8호선)
# 3  서울교통공사  8호선  남한산성입구(성남법원·검찰청)   경기도 성남시 수정구 단대동 96 남한산성입구역(8호선)
# 4  서울교통공사  8호선             단대오거리  경기도 성남시 수정구 신흥동 2467 단대오거리역(8호선)
#
#                        도로명주소                 x                 y         lng  \
# 0    서울특별시 송파구 송파대로 257(가락동)  966274.643182304  1943789.80882922  127.118486
# 1    서울특별시 강동구 올림픽로 550(성내동)  966476.463850377  1947997.66836326  127.120577
# 2   경기도 성남시 수정구 공원로 601(복정동)  968101.715614944  1940492.23585887  127.139297
# 3  경기도 성남시 수정구 산성대로 445(단대동)  969879.995846025  1939212.00958787  127.159458
# 4  경기도 성남시 수정구 산성대로 365(신흥동)  969616.750438634  1938475.47499339  127.156512
#
#          lat
# 0  37.492745
# 1  37.530680
# 2  37.463087
# 3  37.451608
# 4  37.444960

# %%
#5  university  .. 시각화 .. 초기 중심값 좌표가 들어가야 합니다.

# 서울시 중심부 위도, 경도
center = [37.541, 126.986]

# map이 서울 중심부에 위치하고, zoom 레벨은 12로 시작합니다.
map = folium.Map(
    location=center,
    zoom_start=12

)

print('슝~')
# Out:
# 슝~

# %%
#2. 프로젝트(1)  # MarkerCluster 객체 
marker_cluster = MarkerCluster().add_to(map)

#maker 객체 추가
for idx, row in subway_info_df.iterrows():
    try:
        folium.Marker(
            location=[subway_info_df.loc[idx, "lat"], subway_info_df.loc[idx, "lng"]],
            popup=subway_info_df.loc[idx, "역명"],
            icon=folium.Icon(color="cadetblue", icon="flag")            
        ).add_to(marker_cluster)
    except:
        pass

print('슝~')
# Out:
# 슝~

# %%
#5 seoul university 
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5133580130279e8f82b16af205543002 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5133580130279e8f82b16af205543002&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5133580130279e8f82b16af205543002 = L.map(
#                 &quot;map_5133580130279e8f82b16af205543002&quot;,
#                 {
#                     center: [37.541, 126.986],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ad2a5a7387a512db3b1f28ae9bd0916d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5133580130279e8f82b16af205543002);
#
#
#             var marker_cluster_eb87692f7c7e795bf2db253f3a16d2ba = L.markerClusterGroup(
#                 {}
#             );
#             map_5133580130279e8f82b16af205543002.addLayer(marker_cluster_eb87692f7c7e795bf2db253f3a16d2ba);
#
#
#             var marker_2edf3d2cbfe2ec80eb25b48af5c50456 = L.marker(
#                 [37.49274529285958, 127.11848624140217],
#                 {}
#             ).addTo(marker_cluster_eb87692f7c7e795bf2db253f3a16d2ba);
#
#
#             var icon_85dd1dc4208ca8ce5a7eeab5a1b56480 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;flag&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2edf3d2cbfe2ec80eb25b48af5c50456.setIcon(icon_85dd1dc4208ca8ce5a7eeab5a1b56480);
#
#
#         var popup_81164f19022b085f05de44c8a096c22d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aa0666f1382415ac1b96022a8404c653 = $(`&lt;div id=&quot;html_aa0666f1382415ac1b96022a8404c653&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;가락시장&lt;/div&gt;`)[0];
#                 popup_81164f19022b085f05de44c8a096c22d.setContent(html_aa0666f1382415ac1b96022a8404c653);
#
#
#
#         marker_2edf3d2cbfe2ec80eb25b48af5c50456.bindPopup(popup_81164f19022b085f05de44c8a096c22d)
#         ;
#
#
#
#
#             var marker_5b2b73e13cc1b9efe6d9247cc42757d7 = L.marker(
#                 [37.53067997813157, 127.12057732112673],
#                 {}
#             ).addTo(marker_cluster_eb87692f7c7e795bf2db253f3a16d2ba);
#
#
#             var icon_366c8a13ad4b6eb8b53ad5e2a118cf45 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;flag&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5b2b73e13cc1b9efe6d9247cc42757d7.setIcon(icon_366c8a13ad4b6eb8b53ad5e2a118cf45);
#
#
#         var popup_eeb25f574495cda7302997fd8136c9dc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ccbe648dfad02d52f52d056b67f3018a = $(`&lt;div id=&quot;html_ccbe648dfad02d52f52d056b67f3018a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강동구청&lt;/div&gt;`)[0];
#                 popup_eeb25f574495cda7302997fd8136c9dc.setContent(html_ccbe648dfad02d52f52d056b67f3018a);
#
#
#
#         marker_5b2b73e13cc1b9efe6d9247cc42757d7.bindPopup(popup_eeb25f574495cda7302997fd8136c9dc)
#         ;
#
#
#
#
#             var marker_f3a32418c0c53a0000493f0e58720e8e = L.marker(
#                 [37.46308748568515, 127.13929726737683],
#                 {}
#             ).addTo(marker_cluster_eb87692f7c7e795bf2db253f3a16d2ba);
#
#
#             var icon_2243f35d522c2e95e6a0e981e934a9d8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;flag&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f3a32418c0c53a0000493f0e58720e8e.setIcon(icon_2243f35d522c2e95e6a0e981e934a9d8);
#
#
#         var popup_4c879b8f3f74fbeec42ef2715c45aae3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c8708fb6820a56acf48e11940893f0fb = $(`&lt;div id=&quot;html_c870

# %%
map.save("c:/Users/User/000_my_jupyter/900_aiffel/0000_AIFFELTHON/3김연수/003_map_xml/subway_info_08.html")

# %%
#apt_df.to_excel("C:/Users/User/000_my_jupyter/900_aiffel/0000_AIFFELTHON/data/apt_cn_sung.xls", index = False)
# subway_info_df.to_csv("c:/Users/User/000_my_jupyter/900_aiffel/0000_AIFFELTHON/3김연수/002_data_dir/003_search_data/subway_info_02.csv", index = False)
subway_info_df.to_csv("subway_info_08.csv", index = False)
