# %%
import pandas as pd
import os
import numpy as np

# %%
path = 'c:/users/user/000_my_jupyter/900_aiffel/0000_AIFFELTHON/3김연수/002_data_dir/003_search_data/환승data.csv'

df = pd.read_csv(path)
df.head()
# Out:
#   환승시작역\t,\t환승시작 호선
# 0      복정\t,\t수인분당선
# 1        대곡\t,\t경의선
# 2        가좌\t,\t경의선
# 3        문산\t,\t경의선
# 4     효창공원앞\t,\t경의선

# %%
list = []
for i in range(len(df)):
    x = df['환승시작역\t,\t환승시작 호선'][i]
    list.append(x.split('\t'))

# %%
list
# Out:
# [['복정', ',', '수인분당선'],
#  ['대곡', ',', '경의선'],
#  ['가좌', ',', '경의선'],
#  ['문산', ',', '경의선'],
#  ['효창공원앞', ',', '경의선'],
#  ['청구', ',', '5'],
#  ['합정', ',', '6'],
#  ['인천', ',', '수인분당선'],
#  ['주안', ',', '인천2'],
#  ['인천시청', ',', '인천2'],
#  ['석남', ',', '7'],
#  ['기흥', ',', '용인경전철'],
#  ['모란', ',', '8'],
#  ['온수', ',', '1'],
#  ['삼각지', ',', '6'],
#  ['마곡나루', ',', '공항철도'],
#  ['계양', ',', '공항철도'],
#  ['신길온천', ',', '4'],
#  ['정왕', ',', '4'],
#  ['대림', ',', '2'],
#  ['소사', ',', '서해선'],
#  ['이촌', ',', '경의선'],
#  ['신내', ',', '6'],
#  ['용산', ',', '경의선'],
#  ['노량진', ',', '9'],
#  ['수서', ',', '수인분당선'],
#  ['검암', ',', '공항철도'],
#  ['인천공항1터미널', ',', '자기부상철도'],
#  ['오이도', ',', '4'],
#  ['원인재', ',', '인천1'],
#  ['가락시장', ',', '3'],
#  ['이매', ',', '수인분당선'],
#  ['부평', ',', '인천1'],
#  ['신길', ',', '5'],
#  ['까치산', ',', '2'],
#  ['옥수', ',', '경의선'],
#  ['약수', ',', '3'],
#  ['충무로', ',', '4'],
#  ['불광', ',', '6'],
#  ['연신내', ',', '6'],
#  ['초지', ',', '수인분당선'],
#  ['초지', ',', '4'],
#  ['여의도', ',', '9'],
# ...

# %%
df1 = pd.DataFrame(list)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231 entries, 0 to 230
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       231 non-null    object
#  1   1       231 non-null    object
#  2   2       231 non-null    object
# dtypes: object(3)
# memory usage: 5.5+ KB

# %%
df['환승'] = df['환승시작역\t,\t환승시작 호선']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231 entries, 0 to 230
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   환승시작역	,	환승시작 호선  231 non-null    object
#  1   환승시작역            231 non-null    object
#  2   환승               0 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 5.5+ KB

# %%
df1.to_csv("환승data.csv",mode="w",encoding='euc-kr')
