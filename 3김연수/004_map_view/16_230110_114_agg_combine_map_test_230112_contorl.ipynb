# %% [markdown]
#     16_230110_114_agg_combine_map

# %%
#1. package load
import requests
import json
import os
import math
import time
import numpy as np
import pandas as pd
import geopandas as gpd
import pyproj
import folium
import matplotlib.pyplot as plt
import seaborn as sns

from shapely.geometry import mapping, shape, Point, Polygon, LineString
from folium import plugins
from folium.plugins import MarkerCluster, HeatMap

import warnings
warnings.filterwarnings(action='ignore') 

print(pd.__version__)
print(gpd.__version__)
print(folium.__version__)
# Out:
# 1.3.3
# 0.10.1
# 0.12.1

# %%
#2. 프로젝트(1)  ... data load
#path = os.getenv('HOME') + '/aiffel/socar_gis/data/20210823_socar_zone.csv'
path = '/aiffel/aiffel/000_aiffelthon_230111/3김연수/002_data_dir/004_node_data/20210823_socar_zone.csv'

socar_zone_info_df = pd.read_csv(path)
socar_zone_info_df.head()
# Out:
#       zone_name         lng        lat region1  region2 region3
# 0    비전2 파출소사거리  127.102939  36.995989     경기도      평택시     비전동
# 1    수원시청역 9번출구  127.032953  37.262378     경기도  수원시　팔달구     인계동
# 2  목포 상동현대아파트 앞  126.415655  34.811289    전라남도      목포시      상동
# 3   단국대 산학협력관 앞  127.166626  36.832965    충청남도  천안시　동남구     신부동
# 4       목원대학교 앞  127.337858  36.329906   대전광역시       서구     도안동

# %%
k_socar_zone_df = socar_zone_info_df[socar_zone_info_df['region1'] == '경기도']

# %%
# seoul_group_data = socar_zone_info_df.loc[socar_zone_info_df['region1'] == '경기도'].groupby('region2')['region2'].count()
# seoul_group_data

# %% [markdown]
#     2. 프로젝트(1) 서울시 쏘카존 데이터를 활용한 시각화
#        1) data load : socar zone data
#        2) 시각화

# %%
# #2. 프로젝트(1)  # base nap : 서울시 중심부 위도, 경도
# center = [37.541, 126.986]

# map = folium.Map(
#     location=center,
#     zoom_start=10,
#     )
# print('슝~')

# %%
# #2. 프로젝트(1)  # MarkerCluster 객체 
# marker_cluster = MarkerCluster().add_to(map)

# #maker 객체 추가
# for idx, row in socar_zone_info_df.iterrows():
#     try:
#         folium.Marker(
#             location=[socar_zone_info_df.loc[idx, "lat"], socar_zone_info_df.loc[idx, "lng"]],
#             popup=socar_zone_info_df.loc[idx, "zone_name"],
#             icon=folium.Icon(color="cadetblue", icon="car", prefix="fa")            
#         ).add_to(marker_cluster)
#     except:
#         pass

# print('슝~')

# %%
#2. 프로젝트(1)  # map draw
# map

# %%
# #3. 프로젝트(2) ... 1) 카페data 전처리 ... # 카페 위치데이터 리스트 만들기
# seoul_cafe_location_data = [[row["위도"], row["경도"]] for _, row in seoul_cafe_store_df.iterrows()]

# print("슝~")

# %%
# #3. 프로젝트(2) ... 2) 버스data load
# path = os.getenv('HOME') + '??????'
# bus_line_info_df =  pd.read_csv(path)
# bus_line_info_df.head()

# %%
# #3. 프로젝트(2) ... 2) 버스data 전처리 .. 컬럼명 변경
# bus_line_info_df.rename(
#     columns={
#         "Y좌표": "lat",
#         "X좌표": "lng",
#     },
#     inplace=True
# )

# bus_line_info_df.info()

# %%
# #3. 프로젝트(2) ... 2) 버스 정류장 위치데이터 리스트 만들기
# bus_station_location_data = [[row["lat"], row["lng"]] for _, row in bus_line_info_df.iterrows()]
# print('슝~')
# #bus_station_location_data

# %%
#3.  행복주택 load
path = os.getenv('HOME') + '/aiffel/000_aiffelthon_230111/3김연수/002_data_dir/003_search_data/happy_house.csv'
happy_house_df = pd.read_csv(path)
happy_house_df.head()
# Out:
#         지역                      단지  세대수                     주소         위도  \
# 0  고양시 덕양구                  삼송11단지  832    경기도 고양시 덕양구 원흥1로 25  37.650992
# 1  고양시 덕양구  고양지축 A-1블록 신혼희망타운 행복주택  250    경기도 고양시 덕양구 오부자로 99  37.653331
# 2  고양시 덕양구         고양지축 A-4BL 행복주택  473    경기도 고양시 덕양구 오부자로 43  37.654038
# 3  고양시 덕양구         고양삼송 LH원흥마을13단지  947    경기도 고양시 덕양구 원흥1로 35  37.652631
# 4  고양시 덕양구              서정마을LH12단지  276  경기도 고양시 덕양구 서정마을2로 17  37.621215
#
#            경도              x             y         lng        lat
# 0  126.865491  944033.138640  1.961510e+06  126.865540  37.651375
# 1  126.921037  948927.188681  1.961564e+06  126.921014  37.652148
# 2  126.914946  948402.245222  1.961752e+06  126.915050  37.653817
# 3  126.868888  944239.664819  1.961600e+06  126.867874  37.652197
# 4  126.847648  942442.993027  1.958197e+06  126.847776  37.621419

# %%
happy_house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역      95 non-null     object
#  1   단지      95 non-null     object
#  2   세대수     95 non-null     int64
#  3   주소      95 non-null     object
#  4   위도      95 non-null     float64
#  5   경도      95 non-null     float64
#  6   x       92 non-null     float64
#  7   y       92 non-null     float64
#  8   lng     92 non-null     float64
#  9   lat     92 non-null     float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 7.5+ KB

# %%
happy_house_df[happy_house_df['lat'].isnull()]
# Out:
#       지역          단지  세대수                주소         위도          경도   x   y  \
# 20  남양주시  남양주금곡 행복주택  352  경기도 남양주시 경춘로 899  37.633148  127.201262 NaN NaN
# 62   파주시  노을빛마을 16단지  320   경기도 파주시 노을빛로 41  37.726922  126.706746 NaN NaN
# 71   포천시         non    0               non   0.000000    0.000000 NaN NaN
#
#     lng  lat
# 20  NaN  NaN
# 62  NaN  NaN
# 71  NaN  NaN

# %%
happy_house_df = happy_house_df.dropna(axis=0)

# %%
happy_house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 92 entries, 0 to 94
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역      92 non-null     object
#  1   단지      92 non-null     object
#  2   세대수     92 non-null     int64
#  3   주소      92 non-null     object
#  4   위도      92 non-null     float64
#  5   경도      92 non-null     float64
#  6   x       92 non-null     float64
#  7   y       92 non-null     float64
#  8   lng     92 non-null     float64
#  9   lat     92 non-null     float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 7.9+ KB

# %%
#3.  대학교 load
path = os.getenv('HOME') + '/aiffel/000_aiffelthon_230111/3김연수/002_data_dir/003_search_data/k_university.csv'
k_university_df = pd.read_csv(path)
k_university_df.head()
# Out:
#   학교구분  학교코드     학교명 본분교   학제  지역 설립구분   관련법령    법인명 학교상태  ...   우편번호  \
# 0   대학  37.0   한경대학교  본교  대학교  경기   국립  고등교육법   해당없음   기존  ...  17579
# 1   대학  46.0  가톨릭대학교  본교  대학교  경기   사립  고등교육법  가톨릭학원   기존  ...  14662
# 2   대학  51.0   강남대학교  본교  대학교  경기   사립  고등교육법   강남학원   기존  ...  16979
# 3   대학  56.0   경기대학교  본교  대학교  경기   사립  고등교육법   경기학원   기존  ...  16227
# 4   대학  63.0   가천대학교  본교  대학교  경기   사립  고등교육법   가천학원   기존  ...  13120
#
#         학교개교일              학교홈페이지  총장(대학원장)명    학교대표\r\n번호  학교대표\r\n팩스번호  \
# 0  2012-03-01      www.hknu.ac.kr        이원희  031-670-5114  031-670-5469
# 1  1995-03-01  www.catholic.ac.kr        원종철  02-2164-4114  02-2164-4754
# 2  1948-08-12   www.kangnam.ac.kr        윤신일  031-280-3500  031-280-3173
# 3  1947-11-08   www.kyonggi.ac.kr  전준철(직무대행)  031-249-9114  031-243-2194
# 4  2012-03-01    www.gachon.ac.kr        이길여  031-750-5114  031-753-8828
#
#                x             y         lng        lat
# ...

# %%
k_university_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   학교구분         248 non-null    object
#  1   학교코드         248 non-null    float64
#  2   학교명          248 non-null    object
#  3   본분교          248 non-null    object
#  4   학제           248 non-null    object
#  5   지역           248 non-null    object
#  6   설립구분         248 non-null    object
#  7   관련법령         248 non-null    object
#  8   법인명          248 non-null    object
#  9   학교상태         248 non-null    object
#  10  중문학교명        247 non-null    object
#  11  영문학교명        247 non-null    object
#  12  addr         249 non-null    object
#  13  주소           248 non-null    object
#  14  Unnamed: 14  248 non-null    object
#  15  Unnamed: 15  248 non-null    object
#  16  Unnamed: 16  248 non-null    object
#  17  영문주소         247 non-null    object
# ...

# %%
k_university_df[k_university_df['lat'].isnull()]
# Out:
#       학교구분    학교코드              학교명    본분교     학제   지역 설립구분   관련법령  \
# 71   대학원대학   672.0       실천신학대학원대학교     본교  전문대학원   경기   사립  고등교육법
# 184   전문대학  2641.0            경복대학교     본교   전문대학   경기   사립  고등교육법
# 208    대학원  2859.0  예원예술대학교 문화예술대학원  제2캠퍼스  특수대학원   경기   사립  고등교육법
# 248    NaN     NaN              NaN    NaN    NaN  NaN  NaN    NaN
#
#             법인명 학교상태  ...   우편번호       학교개교일                   학교홈페이지  \
# 71      실천신학대학원   기존  ...  17304  2005-03-01           www.gspt.ac.kr
# 184  학교법인 경복대학교   기존  ...  12051  1991-11-30            www.kbu.ac.kr
# 208     예원예술대학교   기존  ...  11429  2014-03-01  www.culture.yewon.ac.kr
# 248         NaN  NaN  ...    NaN         NaN                      NaN
#
#     총장(대학원장)명    학교대표\r\n번호  학교대표\r\n팩스번호   x   y lng lat
# 71        이정익  031-638-8657  031-638-8659 NaN NaN NaN NaN
# 184       전지용  031-570-9901  031-570-9929 NaN NaN NaN NaN
# 208       차종순  031-869-0526  031-859-8114 NaN NaN NaN NaN
# ...

# %%
k_university_df = k_university_df.dropna(axis=0)

# %%
k_university_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 239 entries, 0 to 246
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   학교구분         239 non-null    object
#  1   학교코드         239 non-null    float64
#  2   학교명          239 non-null    object
#  3   본분교          239 non-null    object
#  4   학제           239 non-null    object
#  5   지역           239 non-null    object
#  6   설립구분         239 non-null    object
#  7   관련법령         239 non-null    object
#  8   법인명          239 non-null    object
#  9   학교상태         239 non-null    object
#  10  중문학교명        239 non-null    object
#  11  영문학교명        239 non-null    object
#  12  addr         239 non-null    object
#  13  주소           239 non-null    object
#  14  Unnamed: 14  239 non-null    object
#  15  Unnamed: 15  239 non-null    object
#  16  Unnamed: 16  239 non-null    object
#  17  영문주소         239 non-null    object
# ...

# %%
# #2. 프로젝트(1)  # MarkerCluster 객체 
# marker_cluster = MarkerCluster().add_to(map)

# #maker 객체 추가
# for idx, row in k_university_df.iterrows():
#     try:
#         folium.Marker(
#             location=[apt_df.loc[idx, "lat"], apt_df.loc[idx, "lng"]],
#             popup=apt_df.loc[idx, "학교명"],
#             icon=folium.Icon(color="cadetblue", icon="house")            
#         ).add_to(marker_cluster)
#     except:
#         pass

# print('슝~')

# %%
#4 경기 구 data
k_geo_data_path = os.getenv('HOME') + '/aiffel/000_aiffelthon_230111/3김연수/002_data_dir/001_map_data/kyungki_region.json'
k_geo_data = json.load(
    open(k_geo_data_path, encoding="utf-8"))


print('슝~')
# Out:
# 슝~

# %%
k_pop_df = pd.read_excel("/aiffel/aiffel/000_aiffelthon_230111/3김연수/002_data_dir/003_search_data/region_pop.xls")
k_pop_df.head()
# Out:
#    adm_cd    adm_nm     pop
# 0   41820       가평군   62197
# 1   41281   고양시 덕양구  487874
# 2   41285  고양시 일산동구  296590
# 3   41287  고양시 일산서구  290738
# 4   41290       과천시   77775

# %%
# #7 서울시 구별 인구수 데이터 수집 및 시각화 ..  data add
# folium.Choropleth(
#     geo_data=k_geo_data,
#     name="경기도 인구수",
#     data=k_pop_df,
#     columns=["adm_cd", "pop"],
#     key_on="feature.properties.ADM_SECT_C",
#     fill_color='YlOrRd',
#     fill_opacity=0.7,
#     line_opacity=0.2,
#     line_color='white', 
#     nan_fill_color='blue',
#     line_weight=0,
#     highlight=False, 
#     smooth_factor=1.0,
#     legend_name="인구수"
# ).add_to(map)

# %%
# k_pop_df['adm_cd'] = k_pop_df['adm_cd'].astype(str)

# %%
center = [37.541, 126.986]

map = folium.Map(
    location=center,
    zoom_start= 10
)

# %%
# k_geo = folium.GeoJson( k_geo_data,
#                        name='경기도'
#         ).add_child(map)

# %%
# choropleth.geojson.add_child(folium.features.GeoJsonTooltip(['tooltip1'], labels=False))

# %%
#4. 프로젝트(3)  .. # 2)레이어 적용을 위한 그룹 만들기
# 대표 그룹 만들기
fg = folium.FeatureGroup(name="groups")
map.add_child(fg)

# 행복주택 그룹 만들기
happy = plugins.FeatureGroupSubGroup(fg, "happy house")
map.add_child(happy)

# 대학교 그룹 만들기
university = plugins.FeatureGroupSubGroup(fg, "university")
map.add_child(university)

# 쏘카 그룹 만들기
socar = plugins.FeatureGroupSubGroup(fg, "socar_zone")
map.add_child(socar)

# 레이어 콘트롤 박스 만들기
folium.LayerControl(collapsed=False).add_to(map)

# %%
#3. 행복주택 위치데이터 리스트 만들기
happy_house_data = [[row["lat"], row["lng"]] for _, row in happy_house_df.iterrows()]

popups = [happy_house_df.loc[idx, "단지"] for idx, row in happy_house_df.iterrows()] #popup시 표시 될 주소

mg1 = plugins.MarkerCluster( happy_house_data, popups=popups,control=False)

# map.add_child(mg3)

# %%
    folium.Marker(com_location,
              popup=com_popup
              icon=folium.Icon(color='red', icon='info-sign')
              ).add_to(cluster)

# %%
#3. 대학교 위치데이터 리스트 만들기
k_university_data = [[row["lat"], row["lng"]] for _, row in k_university_df.iterrows()]

popups = [k_university_df.loc[idx, "학교명"] for idx, row in k_university_df.iterrows()] #popup시 표시 될 주소

mg2 = plugins.MarkerCluster( k_university_data, popups=popups,control=False)

# map.add_child(mg2)

# %%
#4. 프로젝트(3)  ..3) 쏘카존 마커 클러스터 만들기
socar_zone_data = [[row["lat"], row["lng"]] for _, row in k_socar_zone_df.iterrows()]
popups = [k_socar_zone_df.loc[idx, "zone_name"] for idx, row in k_socar_zone_df.iterrows()] #popup시 표시 될 주소

mg3 = plugins.MarkerCluster( socar_zone_data, popups=popups,control=False)


# map.add_child(mg1)

# %%
#4. 프로젝트(2) ... 3)시각화  ... # Folium 초기 Map 객체 생성 

# center = [37.541, 126.986]

# map = folium.Map(
#     location=center,
#     zoom_start= 10
# )

# folium.GeoJson(
#     k_geo_data,
#     name='경기도'
# ).add_to(map)

# print('슝~')

# %%
#4. 프로젝트(3)  ..6) 생성한 map 확인

map
map.add_child(mg1)
map.add_child(mg2)
map.add_child(mg3)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
# #3. 프로젝트(2) ... 3) 시각화 .. # 카페 밀도
# plugins.HeatMap(seoul_cafe_location_data)????.add_to(happy)

# %%
# fg = folium.FeatureGroup()                          # Main group
# g1 = folium.plugins.FeatureGroupSubGroup(fg, 'g1')  # First subgroup of fg
# g2 = folium.plugins.FeatureGroupSubGroup(fg, 'g2')  # Second subgroup of fg
# m.add_child(fg)
# m.add_child(g1)
# m.add_child(g2)
# happy.add_child(folium.Marker([0,0]))
# university.add_child(folium.Marker([0,1]))
# soacr.add_child(folium.Marker([0,0]))
# folium.LayerControl().add_to(map)
