# %%
# LSTM for international airline passengers problem with time step regression framing
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return np.array(dataX), np.array(dataY)

# %%
# fix random seed for reproducibility
tf.random.set_seed(7)
# load the dataset
dataframe = read_csv('airline-passengers.csv', usecols=[1], engine='python')
dataset = dataframe.values
dataset = dataset.astype('float32')
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# %%
# reshape into X=t and Y=t+1
look_back = 3
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# %%
# reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1))

# %%
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(look_back, 1)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calculate root mean squared error
trainScore = np.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = np.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# shift train predictions for plotting
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# Epoch 1/100
# 92/92 - 4s - loss: 0.0643 - 4s/epoch - 42ms/step
# Epoch 2/100
# 92/92 - 0s - loss: 0.0276 - 263ms/epoch - 3ms/step
# Epoch 3/100
# 92/92 - 0s - loss: 0.0199 - 263ms/epoch - 3ms/step
# Epoch 4/100
# 92/92 - 0s - loss: 0.0179 - 262ms/epoch - 3ms/step
# Epoch 5/100
# 92/92 - 0s - loss: 0.0163 - 257ms/epoch - 3ms/step
# Epoch 6/100
# 92/92 - 0s - loss: 0.0150 - 250ms/epoch - 3ms/step
# Epoch 7/100
# 92/92 - 0s - loss: 0.0136 - 257ms/epoch - 3ms/step
# Epoch 8/100
# 92/92 - 0s - loss: 0.0124 - 252ms/epoch - 3ms/step
# Epoch 9/100
# 92/92 - 0s - loss: 0.0111 - 262ms/epoch - 3ms/step
# Epoch 10/100
# 92/92 - 0s - loss: 0.0099 - 261ms/epoch - 3ms/step
# Epoch 11/100
# 92/92 - 0s - loss: 0.0089 - 252ms/epoch - 3ms/step
# Epoch 12/100
# 92/92 - 0s - loss: 0.0080 - 251ms/epoch - 3ms/step
# Epoch 13/100
# 92/92 - 0s - loss: 0.0072 - 272ms/epoch - 3ms/step
# Epoch 14/100
# 92/92 - 0s - loss: 0.0067 - 250ms/epoch - 3ms/step
# Epoch 15/100
# 92/92 - 0s - loss: 0.0059 - 243ms/epoch - 3ms/step
# Epoch 16/100
# 92/92 - 0s - loss: 0.0053 - 246ms/epoch - 3ms/step
# Epoch 17/100
# 92/92 - 0s - loss: 0.0051 - 243ms/epoch - 3ms/step
# Epoch 18/100
# 92/92 - 0s - loss: 0.0049 - 248ms/epoch - 3ms/step
# Epoch 19/100
# 92/92 - 0s - loss: 0.0046 - 250ms/epoch - 3ms/step
# Epoch 20/100
# 92/92 - 0s - loss: 0.0045 - 244ms/epoch - 3ms/step
# Epoch 21/100
# 92/92 - 0s - loss: 0.0044 - 242ms/epoch - 3ms/step
# Epoch 22/100
# 92/92 - 0s - loss: 0.0045 - 249ms/epoch - 3ms/step
# Epoch 23/100
# 92/92 - 0s - loss: 0.0044 - 247ms/epoch - 3ms/step
# Epoch 24/100
# 92/92 - 0s - loss: 0.0044 - 254ms/epoch - 3ms/step
# Epoch 25/100
# 92/92 - 0s - loss: 0.0044 - 252ms/epoch - 3ms/step
# Epoch 26/100
# 92/92 - 0s - loss: 0.0043 - 263ms/epoch - 3ms/step
# Epoch 27/100
# 92/92 - 0s - loss: 0.0042 - 251ms/epoch - 3ms/step
# Epoch 28/100
# 92/92 - 0s - loss: 0.0043 - 260ms/epoch - 3ms/step
# Epoch 29/100
# 92/92 - 0s - loss: 0.0042 - 314ms/epoch - 3ms/step
# Epoch 30/100
# 92/92 - 0s - loss: 0.0042 - 248ms/epoch - 3ms/step
# Epoch 31/100
# 92/92 - 0s - loss: 0.0043 - 243ms/epoch - 3ms/step
# Epoch 32/100
# 92/92 - 0s - loss: 0.0042 - 238ms/epoch - 3ms/step
# Epoch 33/100
# 92/92 - 0s - loss: 0.0043 - 249ms/epoch - 3ms/step
# Epoch 34/100
# 92/92 - 0s - loss: 0.0043 - 248ms/epoch - 3ms/step
# Epoch 35/100
# 92/92 - 0s - loss: 0.0042 - 248ms/epoch - 3ms/step
# Epoch 36/100
# 92/92 - 0s - loss: 0.0042 - 236ms/epoch - 3ms/step
# Epoch 37/100
# 92/92 - 0s - loss: 0.0041 - 240ms/epoch - 3ms/step
# Epoch 38/100
# 92/92 - 0s - loss: 0.0040 - 263ms/epoch - 3ms/step
# Epoch 39/100
# 92/92 - 0s - loss: 0.0041 - 243ms/epoch - 3ms/step
# Epoch 40/100
# 92/92 - 0s - loss: 0.0041 - 248ms/epoch - 3ms/step
# Epoch 41/100
# 92/92 - 0s - loss: 0.0040 - 236ms/epoch - 3ms/step
# Epoch 42/100
# 92/92 - 0s - loss: 0.0041 - 236ms/epoch - 3ms/step
# Epoch 43/100
# 92/92 - 0s - loss: 0.0040 - 243ms/epoch - 3ms/step
# Epoch 44/100
# 92/92 - 0s - loss: 0.0040 - 243ms/epoch - 3ms/step
# Epoch 45/100
# 92/92 - 0s - loss: 0.0040 - 252ms/epoch - 3ms/step
# Epoch 46/100
# 92/92 - 0s - loss: 0.0039 - 249ms/epoch - 3ms/step
# Epoch 47/100
# 92/92 - 0s - loss: 0.0039 - 250ms/epoch - 3ms/step
# Epoch 48/100
# 92/92 - 0s - loss: 0.0039 - 249ms/epoch - 3ms/step
# Epoch 49/100
# 92/92 - 0s - loss: 0.0038 - 254ms/epoch - 3ms/step
# Epoch 50/100
# 92/92 - 0s - loss: 0.0038 - 244ms/epoch - 3ms/step
# Epoch 51/100
# 92/92 - 0s - loss: 0.0039 - 251ms/epoch - 3ms/step
# Epoch 52/100
# 92/92 - 0s - loss: 0.0037 - 254ms/epoch - 3ms/step
# Epoch 53/100
# 92/92 - 0s - loss: 0.0036 - 260ms/epoch - 3ms/step
# Epoch 54/100
# 92/92 - 0s - loss: 0.0039 - 246ms/epoch - 3ms/step
# Epoch 55/100
# 92/92 - 0s - loss: 0.0038 - 244ms/epoch - 3ms/step
# Epoch 56/100
# 92/92 - 0s - loss: 0.0039 - 239ms/epoch - 3ms/step
# Epoch 57/100
# 92/92 - 0s - loss: 0.0038 - 249ms/epoch - 3ms/step
# Epoch 58/100
# 92/92 - 0s - loss: 0.0037 - 253ms/epoch - 3ms/step
# Epoch 59/100
# 92/92 - 0s - loss: 0.0038 - 264ms/epoch - 3ms/step
# Epoch 60/100
# 92/92 - 0s - loss: 0.0038 - 258ms/epoch - 3ms/step
# Epoch 61/100
# 92/92 - 0s - loss: 0.0038 - 337ms/epoch - 4ms/step
# Epoch 62/100
# 92/92 - 0s - loss: 0.0038 - 264ms/epoch - 3ms/step
# Epoch 63/100
# 92/92 - 0s - loss: 0.0037 - 265ms/epoch - 3ms/step
# Epoch 64/100
# 92/92 - 0s - loss: 0.0036 - 243ms/epoch - 3ms/step
# Epoch 65/100
# 92/92 - 0s - loss: 0.0037 - 250ms/epoch - 3ms/step
# Epoch 66/100
# 92/92 - 0s - loss: 0.0036 - 250ms/epoch - 3ms/step
# Epoch 67/100
# 92/92 - 0s - loss: 0.0036 - 247ms/epoch - 3ms/step
# Epoch 68/100
# 92/92 - 0s - loss: 0.0035 - 247ms/epoch - 3ms/step
# Epoch 69/100
# 92/92 - 0s - loss: 0.0035 - 238ms/epoch - 3ms/step
# Epoch 70/100
# 92/92 - 0s - loss: 0.0035 - 240ms/epoch - 3ms/step
# Epoch 71/100
# 92/92 - 0s - loss: 0.0037 - 265ms/epoch - 3ms/step
# Epoch 72/100
# 92/92 - 0s - loss: 0.0035 - 238ms/epoch - 3ms/step
# Epoch 73/100
# 92/92 - 0s - loss: 0.0035 - 244ms/epoch - 3ms/step
# Epoch 74/100
# 92/92 - 0s - loss: 0.0035 - 245ms/epoch - 3ms/step
# Epoch 75/100
# 92/92 - 0s - loss: 0.0033 - 236ms/epoch - 3ms/step
# Epoch 76/100
# 92/92 - 0s - loss: 0.0033 - 269ms/epoch - 3ms/step
# Epoch 77/100
# 92/92 - 0s - loss: 0.0033 - 286ms/epoch - 3ms/step
# Epoch 78/100
# 92/92 - 0s - loss: 0.0033 - 271ms/epoch - 3ms/step
# Epoch 79/100
# 92/92 - 0s - loss: 0.0033 - 301ms/epoch - 3ms/step
# Epoch 80/100
# 92/92 - 0s - loss: 0.0032 - 258ms/epoch - 3ms/step
# Epoch 81/100
# 92/92 - 0s - loss: 0.0033 - 297ms/epoch - 3ms/step
# Epoch 82/100
# 92/92 - 0s - loss: 0.0032 - 255ms/epoch - 3ms/step
# Epoch 83/100
# 92/92 - 0s - loss: 0.0031 - 244ms/epoch - 3ms/step
# Epoch 84/100
# 92/92 - 0s - loss: 0.0031 - 263ms/epoch - 3ms/step
# Epoch 85/100
# 92/92 - 0s - loss: 0.0031 - 249ms/epoch - 3ms/step
# Epoch 86/100
# 92/92 - 0s - loss: 0.0030 - 249ms/epoch - 3ms/step
# Epoch 87/100
# 92/92 - 0s - loss: 0.0032 - 233ms/epoch - 3ms/step
# Epoch 88/100
# 92/92 - 0s - loss: 0.0030 - 242ms/epoch - 3ms/step
# Epoch 89/100
# 92/92 - 0s - loss: 0.0029 - 245ms/epoch - 3ms/step
# Epoch 90/100
# 92/92 - 0s - loss: 0.0030 - 246ms/epoch - 3ms/step
# Epoch 91/100
# 92/92 - 0s - loss: 0.0029 - 247ms/epoch - 3ms/step
# Epoch 92/100
# 92/92 - 0s - loss: 0.0029 - 235ms/epoch - 3ms/step
# Epoch 93/100
# 92/92 - 0s - loss: 0.0029 - 239ms/epoch - 3ms/step
# Epoch 94/100
# 92/92 - 0s - loss: 0.0029 - 253ms/epoch - 3ms/step
# Epoch 95/100
# 92/92 - 0s - loss: 0.0027 - 246ms/epoch - 3ms/step
# Epoch 96/100
# 92/92 - 0s - loss: 0.0027 - 250ms/epoch - 3ms/step
# Epoch 97/100
# 92/92 - 0s - loss: 0.0028 - 246ms/epoch - 3ms/step
# Epoch 98/100
# 92/92 - 0s - loss: 0.0027 - 241ms/epoch - 3ms/step
# Epoch 99/100
# 92/92 - 0s - loss: 0.0026 - 242ms/epoch - 3ms/step
# Epoch 100/100
# 92/92 - 0s - loss: 0.0025 - 245ms/epoch - 3ms/step
# 3/3 [==============================] - 1s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# Train Score: 27.01 RMSE
# Test Score: 67.83 RMSE
