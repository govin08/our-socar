# %%
# cell 0
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
# cell 1
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# %%
# cell 2
# fix random seed for reproducibility
tf.random.set_seed(7)
# load the dataset
dataframe = pd.read_csv('airline-passengers.csv', usecols=[1], engine='python')
dataset = dataframe.values
dataset = dataset.astype('float32')

# %%
# cell 3
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# %%
# cell 4
# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# %%
# cell 5
# reshape into X=t and Y=t+1
look_back = 3
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# %%
# cell 6
# reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
# cell 7
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)
# Out:
# Epoch 1/100
# 92/92 - 3s - loss: 0.0386 - 3s/epoch - 34ms/step
# Epoch 2/100
# 92/92 - 0s - loss: 0.0179 - 229ms/epoch - 2ms/step
# Epoch 3/100
# 92/92 - 0s - loss: 0.0119 - 221ms/epoch - 2ms/step
# Epoch 4/100
# 92/92 - 0s - loss: 0.0101 - 219ms/epoch - 2ms/step
# Epoch 5/100
# 92/92 - 0s - loss: 0.0089 - 215ms/epoch - 2ms/step
# Epoch 6/100
# 92/92 - 0s - loss: 0.0079 - 211ms/epoch - 2ms/step
# Epoch 7/100
# 92/92 - 0s - loss: 0.0069 - 223ms/epoch - 2ms/step
# Epoch 8/100
# 92/92 - 0s - loss: 0.0061 - 213ms/epoch - 2ms/step
# Epoch 9/100
# 92/92 - 0s - loss: 0.0052 - 215ms/epoch - 2ms/step
# Epoch 10/100
# 92/92 - 0s - loss: 0.0046 - 233ms/epoch - 3ms/step
# Epoch 11/100
# 92/92 - 0s - loss: 0.0042 - 238ms/epoch - 3ms/step
# Epoch 12/100
# 92/92 - 0s - loss: 0.0039 - 214ms/epoch - 2ms/step
# Epoch 13/100
# 92/92 - 0s - loss: 0.0036 - 218ms/epoch - 2ms/step
# Epoch 14/100
# 92/92 - 0s - loss: 0.0036 - 221ms/epoch - 2ms/step
# Epoch 15/100
# 92/92 - 0s - loss: 0.0034 - 219ms/epoch - 2ms/step
# Epoch 16/100
# 92/92 - 0s - loss: 0.0033 - 218ms/epoch - 2ms/step
# Epoch 17/100
# 92/92 - 0s - loss: 0.0033 - 207ms/epoch - 2ms/step
# Epoch 18/100
# 92/92 - 0s - loss: 0.0033 - 225ms/epoch - 2ms/step
# Epoch 19/100
# 92/92 - 0s - loss: 0.0032 - 274ms/epoch - 3ms/step
# Epoch 20/100
# 92/92 - 0s - loss: 0.0031 - 237ms/epoch - 3ms/step
# Epoch 21/100
# 92/92 - 0s - loss: 0.0031 - 224ms/epoch - 2ms/step
# Epoch 22/100
# 92/92 - 0s - loss: 0.0031 - 226ms/epoch - 2ms/step
# Epoch 23/100
# 92/92 - 0s - loss: 0.0030 - 306ms/epoch - 3ms/step
# Epoch 24/100
# 92/92 - 0s - loss: 0.0030 - 251ms/epoch - 3ms/step
# Epoch 25/100
# 92/92 - 0s - loss: 0.0030 - 244ms/epoch - 3ms/step
# Epoch 26/100
# 92/92 - 0s - loss: 0.0030 - 225ms/epoch - 2ms/step
# Epoch 27/100
# 92/92 - 0s - loss: 0.0029 - 234ms/epoch - 3ms/step
# Epoch 28/100
# 92/92 - 0s - loss: 0.0029 - 207ms/epoch - 2ms/step
# Epoch 29/100
# 92/92 - 0s - loss: 0.0029 - 197ms/epoch - 2ms/step
# Epoch 30/100
# 92/92 - 0s - loss: 0.0028 - 209ms/epoch - 2ms/step
# Epoch 31/100
# 92/92 - 0s - loss: 0.0029 - 225ms/epoch - 2ms/step
# Epoch 32/100
# 92/92 - 0s - loss: 0.0028 - 232ms/epoch - 3ms/step
# Epoch 33/100
# 92/92 - 0s - loss: 0.0028 - 217ms/epoch - 2ms/step
# Epoch 34/100
# 92/92 - 0s - loss: 0.0028 - 233ms/epoch - 3ms/step
# Epoch 35/100
# 92/92 - 0s - loss: 0.0028 - 219ms/epoch - 2ms/step
# Epoch 36/100
# 92/92 - 0s - loss: 0.0028 - 236ms/epoch - 3ms/step
# Epoch 37/100
# 92/92 - 0s - loss: 0.0027 - 217ms/epoch - 2ms/step
# Epoch 38/100
# 92/92 - 0s - loss: 0.0026 - 202ms/epoch - 2ms/step
# Epoch 39/100
# 92/92 - 0s - loss: 0.0026 - 203ms/epoch - 2ms/step
# Epoch 40/100
# 92/92 - 0s - loss: 0.0026 - 210ms/epoch - 2ms/step
# Epoch 41/100
# 92/92 - 0s - loss: 0.0026 - 215ms/epoch - 2ms/step
# Epoch 42/100
# 92/92 - 0s - loss: 0.0026 - 210ms/epoch - 2ms/step
# Epoch 43/100
# 92/92 - 0s - loss: 0.0025 - 214ms/epoch - 2ms/step
# Epoch 44/100
# 92/92 - 0s - loss: 0.0025 - 212ms/epoch - 2ms/step
# Epoch 45/100
# 92/92 - 0s - loss: 0.0025 - 199ms/epoch - 2ms/step
# Epoch 46/100
# 92/92 - 0s - loss: 0.0024 - 207ms/epoch - 2ms/step
# Epoch 47/100
# 92/92 - 0s - loss: 0.0024 - 202ms/epoch - 2ms/step
# Epoch 48/100
# 92/92 - 0s - loss: 0.0024 - 210ms/epoch - 2ms/step
# Epoch 49/100
# 92/92 - 0s - loss: 0.0023 - 211ms/epoch - 2ms/step
# Epoch 50/100
# 92/92 - 0s - loss: 0.0023 - 224ms/epoch - 2ms/step
# Epoch 51/100
# 92/92 - 0s - loss: 0.0023 - 202ms/epoch - 2ms/step
# Epoch 52/100
# 92/92 - 0s - loss: 0.0023 - 208ms/epoch - 2ms/step
# Epoch 53/100
# 92/92 - 0s - loss: 0.0022 - 208ms/epoch - 2ms/step
# Epoch 54/100
# 92/92 - 0s - loss: 0.0023 - 224ms/epoch - 2ms/step
# Epoch 55/100
# 92/92 - 0s - loss: 0.0022 - 237ms/epoch - 3ms/step
# Epoch 56/100
# 92/92 - 0s - loss: 0.0023 - 214ms/epoch - 2ms/step
# Epoch 57/100
# 92/92 - 0s - loss: 0.0022 - 213ms/epoch - 2ms/step
# Epoch 58/100
# 92/92 - 0s - loss: 0.0021 - 207ms/epoch - 2ms/step
# Epoch 59/100
# 92/92 - 0s - loss: 0.0022 - 206ms/epoch - 2ms/step
# Epoch 60/100
# 92/92 - 0s - loss: 0.0022 - 222ms/epoch - 2ms/step
# Epoch 61/100
# 92/92 - 0s - loss: 0.0021 - 263ms/epoch - 3ms/step
# Epoch 62/100
# 92/92 - 0s - loss: 0.0022 - 210ms/epoch - 2ms/step
# Epoch 63/100
# 92/92 - 0s - loss: 0.0022 - 207ms/epoch - 2ms/step
# Epoch 64/100
# 92/92 - 0s - loss: 0.0021 - 212ms/epoch - 2ms/step
# Epoch 65/100
# 92/92 - 0s - loss: 0.0021 - 264ms/epoch - 3ms/step
# Epoch 66/100
# 92/92 - 0s - loss: 0.0021 - 207ms/epoch - 2ms/step
# Epoch 67/100
# 92/92 - 0s - loss: 0.0020 - 223ms/epoch - 2ms/step
# Epoch 68/100
# 92/92 - 0s - loss: 0.0020 - 252ms/epoch - 3ms/step
# Epoch 69/100
# 92/92 - 0s - loss: 0.0020 - 242ms/epoch - 3ms/step
# Epoch 70/100
# 92/92 - 0s - loss: 0.0020 - 209ms/epoch - 2ms/step
# Epoch 71/100
# 92/92 - 0s - loss: 0.0021 - 198ms/epoch - 2ms/step
# Epoch 72/100
# 92/92 - 0s - loss: 0.0020 - 204ms/epoch - 2ms/step
# Epoch 73/100
# 92/92 - 0s - loss: 0.0019 - 223ms/epoch - 2ms/step
# Epoch 74/100
# 92/92 - 0s - loss: 0.0020 - 216ms/epoch - 2ms/step
# Epoch 75/100
# 92/92 - 0s - loss: 0.0019 - 211ms/epoch - 2ms/step
# Epoch 76/100
# 92/92 - 0s - loss: 0.0019 - 212ms/epoch - 2ms/step
# Epoch 77/100
# 92/92 - 0s - loss: 0.0019 - 204ms/epoch - 2ms/step
# Epoch 78/100
# 92/92 - 0s - loss: 0.0019 - 222ms/epoch - 2ms/step
# Epoch 79/100
# 92/92 - 0s - loss: 0.0020 - 202ms/epoch - 2ms/step
# Epoch 80/100
# 92/92 - 0s - loss: 0.0019 - 236ms/epoch - 3ms/step
# Epoch 81/100
# 92/92 - 0s - loss: 0.0019 - 240ms/epoch - 3ms/step
# Epoch 82/100
# 92/92 - 0s - loss: 0.0019 - 207ms/epoch - 2ms/step
# Epoch 83/100
# 92/92 - 0s - loss: 0.0019 - 208ms/epoch - 2ms/step
# Epoch 84/100
# 92/92 - 0s - loss: 0.0019 - 290ms/epoch - 3ms/step
# Epoch 85/100
# 92/92 - 0s - loss: 0.0019 - 234ms/epoch - 3ms/step
# Epoch 86/100
# 92/92 - 0s - loss: 0.0019 - 220ms/epoch - 2ms/step
# Epoch 87/100
# 92/92 - 0s - loss: 0.0019 - 213ms/epoch - 2ms/step
# Epoch 88/100
# 92/92 - 0s - loss: 0.0019 - 203ms/epoch - 2ms/step
# Epoch 89/100
# 92/92 - 0s - loss: 0.0019 - 269ms/epoch - 3ms/step
# Epoch 90/100
# 92/92 - 0s - loss: 0.0019 - 261ms/epoch - 3ms/step
# Epoch 91/100
# 92/92 - 0s - loss: 0.0019 - 268ms/epoch - 3ms/step
# Epoch 92/100
# 92/92 - 0s - loss: 0.0020 - 261ms/epoch - 3ms/step
# Epoch 93/100
# 92/92 - 0s - loss: 0.0020 - 251ms/epoch - 3ms/step
# Epoch 94/100
# 92/92 - 0s - loss: 0.0019 - 197ms/epoch - 2ms/step
# Epoch 95/100
# 92/92 - 0s - loss: 0.0018 - 211ms/epoch - 2ms/step
# Epoch 96/100
# 92/92 - 0s - loss: 0.0018 - 227ms/epoch - 2ms/step
# Epoch 97/100
# 92/92 - 0s - loss: 0.0019 - 218ms/epoch - 2ms/step
# Epoch 98/100
# 92/92 - 0s - loss: 0.0018 - 220ms/epoch - 2ms/step
# Epoch 99/100
# 92/92 - 0s - loss: 0.0019 - 213ms/epoch - 2ms/step
# Epoch 100/100
# 92/92 - 0s - loss: 0.0018 - 223ms/epoch - 2ms/step

# %%
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calculate root mean squared error
trainScore = np.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = np.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# shift train predictions for plotting
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# 3/3 [==============================] - 1s 3ms/step
# 2/2 [==============================] - 0s 4ms/step
# Train Score: 22.33 RMSE
# Test Score: 60.22 RMSE

# %%
testPredict, testPredict
# Out:
# (array([[345.23288],
#         [334.18832],
#         [332.10706],
#         [403.10928],
#         [438.53748],
#         [417.2693 ],
#         [341.35242],
#         [293.3977 ],
#         [271.75674],
#         [318.23544],
#         [326.8526 ],
#         [297.94672],
#         [345.53458],
#         [330.51367],
#         [339.26556],
#         [415.8134 ],
#         [461.6748 ],
#         [448.3498 ],
#         [328.19983],
#         [296.26227],
#         [275.41788],
#         [316.6618 ],
#         [347.15457],
#         [320.8634 ],
#         [385.1903 ],
#         [371.45657],
#         [382.84317],
#         [435.6572 ],
#         [498.84436],
#         [482.16025],
#         [360.0913 ],
#         [319.5955 ],
#         [308.7777 ],
#         [371.43842],
#         [389.0428 ],
#         [350.4558 ],
#         [379.794  ],
#         [425.7793 ],
#         [423.80353],
#         [474.02975],
#         [546.5265 ],
#         [494.52267],
#         [370.90787],
#         [350.11508]], dtype=float32),
#  array([[345.23288],
#         [334.18832],
#         [332.10706],
#         [403.10928],
#         [438.53748],
#         [417.2693 ],
#         [341.35242],
#         [293.3977 ],
#         [271.75674],
#         [318.23544],
#         [326.8526 ],
#         [297.94672],
#         [345.53458],
#         [330.51367],
#         [339.26556],
#         [415.8134 ],
#         [461.6748 ],
#         [448.3498 ],
#         [328.19983],
#         [296.26227],
#         [275.41788],
#         [316.6618 ],
#         [347.15457],
#         [320.8634 ],
#         [385.1903 ],
#         [371.45657],
#         [382.84317],
#         [435.6572 ],
#         [498.84436],
#         [482.16025],
#         [360.0913 ],
#         [319.5955 ],
#         [308.7777 ],
#         [371.43842],
#         [389.0428 ],
#         [350.4558 ],
#         [379.794  ],
#         [425.7793 ],
#         [423.80353],
#         [474.02975],
#         [546.5265 ],
#         [494.52267],
#         [370.90787],
#         [350.11508]], dtype=float32))
