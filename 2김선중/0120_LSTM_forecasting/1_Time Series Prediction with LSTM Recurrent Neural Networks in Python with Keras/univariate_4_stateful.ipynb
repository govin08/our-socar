# %%
# LSTM for international airline passengers problem with memory
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return np.array(dataX), np.array(dataY)
# fix random seed for reproducibility
tf.random.set_seed(7)

# %%
# load the dataset
dataframe = read_csv('airline-passengers.csv', usecols=[1], engine='python')
dataset = dataframe.values
dataset = dataset.astype('float32')
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# %%
# reshape into X=t and Y=t+1
look_back = 3
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
# reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1))

# %%
# create and fit the LSTM network
batch_size = 1
model = Sequential()
model.add(LSTM(4, batch_input_shape=(batch_size, look_back, 1), stateful=True))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
for i in range(100):
	model.fit(trainX, trainY, epochs=1, batch_size=batch_size, verbose=2, shuffle=False)
	model.reset_states()
# make predictions
trainPredict = model.predict(trainX, batch_size=batch_size)
model.reset_states()
testPredict = model.predict(testX, batch_size=batch_size)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calculate root mean squared error
trainScore = np.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = np.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# shift train predictions for plotting
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# 92/92 - 4s - loss: 0.0405 - 4s/epoch - 41ms/step
# 92/92 - 0s - loss: 0.0283 - 322ms/epoch - 4ms/step
# 92/92 - 0s - loss: 0.0234 - 235ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0194 - 259ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0164 - 278ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0139 - 250ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0116 - 292ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0096 - 281ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0080 - 284ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0067 - 383ms/epoch - 4ms/step
# 92/92 - 0s - loss: 0.0058 - 294ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0052 - 283ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0049 - 238ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0047 - 239ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0045 - 290ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0044 - 276ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0043 - 251ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0042 - 264ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0042 - 262ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0041 - 256ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0040 - 254ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0040 - 277ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0039 - 291ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0039 - 260ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0038 - 258ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0038 - 291ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0037 - 267ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0037 - 263ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0036 - 264ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0036 - 316ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0035 - 249ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0035 - 259ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0034 - 253ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0034 - 247ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0033 - 228ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0033 - 285ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0032 - 268ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0032 - 257ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0031 - 283ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0031 - 274ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0030 - 269ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0030 - 288ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0030 - 280ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0029 - 239ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0029 - 338ms/epoch - 4ms/step
# 92/92 - 0s - loss: 0.0028 - 331ms/epoch - 4ms/step
# 92/92 - 0s - loss: 0.0028 - 359ms/epoch - 4ms/step
# 92/92 - 0s - loss: 0.0027 - 368ms/epoch - 4ms/step
# 92/92 - 0s - loss: 0.0027 - 368ms/epoch - 4ms/step
# 92/92 - 0s - loss: 0.0027 - 317ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0026 - 285ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0026 - 314ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0026 - 332ms/epoch - 4ms/step
# 92/92 - 0s - loss: 0.0025 - 348ms/epoch - 4ms/step
# 92/92 - 0s - loss: 0.0025 - 322ms/epoch - 4ms/step
# 92/92 - 0s - loss: 0.0025 - 285ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0024 - 253ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0024 - 281ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0024 - 255ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0023 - 246ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0023 - 315ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0023 - 268ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0023 - 254ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0022 - 270ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0022 - 251ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0022 - 253ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0022 - 283ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0021 - 282ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0021 - 258ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0021 - 286ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0021 - 276ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0021 - 287ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0020 - 229ms/epoch - 2ms/step
# 92/92 - 0s - loss: 0.0020 - 253ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0020 - 302ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0020 - 256ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0020 - 267ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0020 - 256ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0019 - 264ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0019 - 237ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0019 - 256ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0019 - 324ms/epoch - 4ms/step
# 92/92 - 0s - loss: 0.0019 - 244ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0019 - 258ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0019 - 268ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0018 - 264ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0018 - 236ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0018 - 267ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0018 - 269ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0018 - 263ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0018 - 270ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0018 - 252ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0018 - 269ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0018 - 263ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0018 - 262ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0017 - 264ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0017 - 273ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0017 - 275ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0017 - 283ms/epoch - 3ms/step
# 92/92 - 0s - loss: 0.0017 - 281ms/epoch - 3ms/step
# 92/92 [==============================] - 1s 2ms/step
# 44/44 [==============================] - 0s 2ms/step
# Train Score: 21.46 RMSE
# Test Score: 48.87 RMSE
